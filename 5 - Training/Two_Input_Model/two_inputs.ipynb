# %%
import json
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./label/labels.csv')
shuffled_df = df.sample(frac=1, random_state=42)

N = shuffled_df.shape[0]

n_train = int(0.8*N)
n_val = int(0.1*N)
n_test = N - n_train - n_val

print(N, n_train, n_val, n_test)
df.head()
# Out:
# 43054 34443 4305 4306
#                               name  label
# 0  kplr000757450-2009350155506_llc      1
# 1  kplr000757450-2010078095331_llc      1
# 2  kplr000757450-2010174085026_llc      1
# 3  kplr000757450-2010265121752_llc      1
# 4  kplr000757450-2010355172524_llc      1

# %%
train_fnames = shuffled_df['name'].values[0:n_train]
train_labels = shuffled_df['label'].values[0:n_train]

val_fnames = shuffled_df['name'].values[n_train:n_train+n_val]
val_labels = shuffled_df['label'].values[n_train:n_train+n_val]

test_fnames = shuffled_df['name'].values[n_train+n_val:]
test_labels = shuffled_df['label'].values[n_train+n_val:]

# %%
import tensorflow as tf

ds_train = tf.data.Dataset.from_tensor_slices((train_fnames,train_labels))
ds_val = tf.data.Dataset.from_tensor_slices((val_fnames,val_labels))
ds_test = tf.data.Dataset.from_tensor_slices((test_fnames,test_labels))
# Out:
# WARNING:tensorflow:From c:\Workspace\TFM_2\Two_Input_Model\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def preprocesar_datos(name, label):
    flux = tf.io.read_file("./data/" + name + "/flux.csv")
    flux = tf.strings.split(flux, sep=',')
    flux = tf.strings.to_number(flux)
    power = tf.io.read_file("./data/" + name + "/power.csv")
    power = tf.strings.split(power, sep=',')
    power = tf.strings.to_number(power)
    return (flux, power), label

# %%
BATCH_SIZE_TRAIN = 100
BATCH_SIZE_VAL = 100

train_batch = ds_train.map(preprocesar_datos).batch(BATCH_SIZE_TRAIN)
val_batch = ds_val.map(preprocesar_datos).batch(BATCH_SIZE_VAL)
ds_test = ds_test.map(preprocesar_datos)

# %%
from tensorflow.keras import layers, Model
#Model Definition

#Inputs
inputFlux = layers.Input((4000,1),)
inputPower = layers.Input((5000,1),)

#Flux branch
x = layers.Conv1D(32, 10, activation='relu')(inputFlux)
x = layers.MaxPool1D(3)(x)
x = layers.Conv1D(32, 10, activation='relu')(x)
x = layers.MaxPool1D(3)(x)
x = layers.Flatten()(x)
x = Model(inputs=inputFlux, outputs=x)

#Power branch
y = layers.Conv1D(32, 10, activation='relu')(inputPower)
y = layers.MaxPool1D(3)(y)
y = layers.Conv1D(32, 10, activation='relu')(y)
y = layers.MaxPool1D(3)(y)
y = layers.Flatten()(y)
y = Model(inputs=inputPower, outputs=y)

combined = layers.concatenate([x.output, y.output])

z = layers.Dense(100, activation='sigmoid')(combined)
z = layers.Dense(10, activation='sigmoid')(z)
z = layers.Dense(1, activation='sigmoid')(z)

model = Model(inputs=[x.input, y.input], outputs=z)
model.summary()
# Out:
# WARNING:tensorflow:From c:\Workspace\TFM_2\Two_Input_Model\.venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Workspace\TFM_2\Two_Input_Model\.venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 4000, 1)]            0         []
#
#  input_2 (InputLayer)        [(None, 5000, 1)]            0         []
#
#  conv1d (Conv1D)             (None, 3991, 32)             352       ['input_1[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 4991, 32)             352       ['input_2[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 1330, 32)             0         ['conv1d[0][0]']
#  D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 1663, 32)             0         ['conv1d_2[0][0]']
#  g1D)
#
#  conv1d_1 (Conv1D)           (None, 1321, 32)             10272     ['max_pooling1d[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 1654, 32)             10272     ['max_pooling1d_2[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 440, 32)              0         ['conv1d_1[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 551, 32)              0         ['conv1d_3[0][0]']
#  g1D)
#
#  flatten (Flatten)           (None, 14080)                0         ['max_pooling1d_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 17632)                0         ['max_pooling1d_3[0][0]']
#
#  concatenate (Concatenate)   (None, 31712)                0         ['flatten[0][0]',
#                                                                      'flatten_1[0][0]']
#
#  dense (Dense)               (None, 100)                  3171300   ['concatenate[0][0]']
#
#  dense_1 (Dense)             (None, 10)                   1010      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    11        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 3193569 (12.18 MB)
# Trainable params: 3193569 (12.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from datetime import datetime
from tensorflow import keras
#Compilación del modelo
model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=[
              keras.metrics.BinaryAccuracy(),
              keras.metrics.Recall(),
              keras.metrics.Precision(),
              keras.metrics.AUC(num_thresholds=25)
            ]
    )

#Definición del directorio donde guardar los datos del entrenamiento
logdir = "./Logs/A/"
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath="./Models/A/best_model.keras",
    verbose=1,
    save_best_only=True,
    mode="max",
    monitor="val_binary_accuracy",
)

# %%
training_history = model.fit(
    train_batch,
    verbose=1, # Suppress chatty output; use Tensorboard instead
    epochs=50,
    validation_data = val_batch,
    callbacks=[tensorboard_callback, model_checkpoint]
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Workspace\TFM_2\Two_Input_Model\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 345/345 [==============================] - ETA: 0s - loss: 0.5783 - binary_accuracy: 0.7134 - recall: 0.8143 - precision: 0.6766 - auc: 0.7696
# Epoch 1: val_binary_accuracy improved from -inf to 0.74564, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 195s 562ms/step - loss: 0.5783 - binary_accuracy: 0.7134 - recall: 0.8143 - precision: 0.6766 - auc: 0.7696 - val_loss: 0.5446 - val_binary_accuracy: 0.7456 - val_recall: 0.8649 - val_precision: 0.7073 - val_auc: 0.8034
# Epoch 2/50
# 345/345 [==============================] - ETA: 0s - loss: 0.5314 - binary_accuracy: 0.7562 - recall: 0.8612 - precision: 0.7109 - auc: 0.8090
# Epoch 2: val_binary_accuracy improved from 0.74564 to 0.77003, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 83s 239ms/step - loss: 0.5314 - binary_accuracy: 0.7562 - recall: 0.8612 - precision: 0.7109 - auc: 0.8090 - val_loss: 0.5105 - val_binary_accuracy: 0.7700 - val_recall: 0.8982 - val_precision: 0.7231 - val_auc: 0.8260
# Epoch 3/50
# 345/345 [==============================] - ETA: 0s - loss: 0.5003 - binary_accuracy: 0.7784 - recall: 0.8903 - precision: 0.7268 - auc: 0.8296
# Epoch 3: val_binary_accuracy improved from 0.77003 to 0.78374, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 82s 239ms/step - loss: 0.5003 - binary_accuracy: 0.7784 - recall: 0.8903 - precision: 0.7268 - auc: 0.8296 - val_loss: 0.4896 - val_binary_accuracy: 0.7837 - val_recall: 0.9149 - val_precision: 0.7325 - val_auc: 0.8371
# Epoch 4/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4806 - binary_accuracy: 0.7896 - recall: 0.9012 - precision: 0.7360 - auc: 0.8402
# Epoch 4: val_binary_accuracy improved from 0.78374 to 0.79233, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 83s 240ms/step - loss: 0.4806 - binary_accuracy: 0.7896 - recall: 0.9012 - precision: 0.7360 - auc: 0.8402 - val_loss: 0.4760 - val_binary_accuracy: 0.7923 - val_recall: 0.9212 - val_precision: 0.7400 - val_auc: 0.8445
# Epoch 5/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4668 - binary_accuracy: 0.7970 - recall: 0.9065 - precision: 0.7429 - auc: 0.8489
# Epoch 5: val_binary_accuracy improved from 0.79233 to 0.79675, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 82s 236ms/step - loss: 0.4668 - binary_accuracy: 0.7970 - recall: 0.9065 - precision: 0.7429 - auc: 0.8489 - val_loss: 0.4671 - val_binary_accuracy: 0.7967 - val_recall: 0.9235 - val_precision: 0.7442 - val_auc: 0.8499
# Epoch 6/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4564 - binary_accuracy: 0.8023 - recall: 0.9099 - precision: 0.7480 - auc: 0.8556
# Epoch 6: val_binary_accuracy improved from 0.79675 to 0.79907, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 228ms/step - loss: 0.4564 - binary_accuracy: 0.8023 - recall: 0.9099 - precision: 0.7480 - auc: 0.8556 - val_loss: 0.4604 - val_binary_accuracy: 0.7991 - val_recall: 0.9235 - val_precision: 0.7469 - val_auc: 0.8535
# Epoch 7/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4479 - binary_accuracy: 0.8055 - recall: 0.9110 - precision: 0.7516 - auc: 0.8604
# Epoch 7: val_binary_accuracy improved from 0.79907 to 0.80232, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 228ms/step - loss: 0.4479 - binary_accuracy: 0.8055 - recall: 0.9110 - precision: 0.7516 - auc: 0.8604 - val_loss: 0.4556 - val_binary_accuracy: 0.8023 - val_recall: 0.9262 - val_precision: 0.7496 - val_auc: 0.8548
# Epoch 8/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4405 - binary_accuracy: 0.8086 - recall: 0.9122 - precision: 0.7549 - auc: 0.8647
# Epoch 8: val_binary_accuracy improved from 0.80232 to 0.80302, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 229ms/step - loss: 0.4405 - binary_accuracy: 0.8086 - recall: 0.9122 - precision: 0.7549 - auc: 0.8647 - val_loss: 0.4518 - val_binary_accuracy: 0.8030 - val_recall: 0.9271 - val_precision: 0.7501 - val_auc: 0.8565
# Epoch 9/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4338 - binary_accuracy: 0.8123 - recall: 0.9146 - precision: 0.7586 - auc: 0.8690
# Epoch 9: val_binary_accuracy improved from 0.80302 to 0.80488, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 228ms/step - loss: 0.4338 - binary_accuracy: 0.8123 - recall: 0.9146 - precision: 0.7586 - auc: 0.8690 - val_loss: 0.4486 - val_binary_accuracy: 0.8049 - val_recall: 0.9275 - val_precision: 0.7521 - val_auc: 0.8590
# Epoch 10/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4274 - binary_accuracy: 0.8152 - recall: 0.9154 - precision: 0.7619 - auc: 0.8738
# Epoch 10: val_binary_accuracy improved from 0.80488 to 0.80650, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 230ms/step - loss: 0.4274 - binary_accuracy: 0.8152 - recall: 0.9154 - precision: 0.7619 - auc: 0.8738 - val_loss: 0.4457 - val_binary_accuracy: 0.8065 - val_recall: 0.9266 - val_precision: 0.7544 - val_auc: 0.8603
# Epoch 11/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4211 - binary_accuracy: 0.8184 - recall: 0.9164 - precision: 0.7655 - auc: 0.8774
# Epoch 11: val_binary_accuracy improved from 0.80650 to 0.80767, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 228ms/step - loss: 0.4211 - binary_accuracy: 0.8184 - recall: 0.9164 - precision: 0.7655 - auc: 0.8774 - val_loss: 0.4436 - val_binary_accuracy: 0.8077 - val_recall: 0.9280 - val_precision: 0.7552 - val_auc: 0.8597
# Epoch 12/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4149 - binary_accuracy: 0.8228 - recall: 0.9188 - precision: 0.7702 - auc: 0.8808
# Epoch 12: val_binary_accuracy improved from 0.80767 to 0.80883, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 229ms/step - loss: 0.4149 - binary_accuracy: 0.8228 - recall: 0.9188 - precision: 0.7702 - auc: 0.8808 - val_loss: 0.4418 - val_binary_accuracy: 0.8088 - val_recall: 0.9271 - val_precision: 0.7570 - val_auc: 0.8595
# Epoch 13/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4089 - binary_accuracy: 0.8258 - recall: 0.9198 - precision: 0.7735 - auc: 0.8842
# Epoch 13: val_binary_accuracy improved from 0.80883 to 0.81022, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 229ms/step - loss: 0.4089 - binary_accuracy: 0.8258 - recall: 0.9198 - precision: 0.7735 - auc: 0.8842 - val_loss: 0.4407 - val_binary_accuracy: 0.8102 - val_recall: 0.9284 - val_precision: 0.7581 - val_auc: 0.8608
# Epoch 14/50
# 345/345 [==============================] - ETA: 0s - loss: 0.4031 - binary_accuracy: 0.8295 - recall: 0.9214 - precision: 0.7777 - auc: 0.8877
# Epoch 14: val_binary_accuracy improved from 0.81022 to 0.81161, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 228ms/step - loss: 0.4031 - binary_accuracy: 0.8295 - recall: 0.9214 - precision: 0.7777 - auc: 0.8877 - val_loss: 0.4393 - val_binary_accuracy: 0.8116 - val_recall: 0.9284 - val_precision: 0.7598 - val_auc: 0.8608
# Epoch 15/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3975 - binary_accuracy: 0.8320 - recall: 0.9227 - precision: 0.7804 - auc: 0.8909
# Epoch 15: val_binary_accuracy did not improve from 0.81161
# 345/345 [==============================] - 79s 229ms/step - loss: 0.3975 - binary_accuracy: 0.8320 - recall: 0.9227 - precision: 0.7804 - auc: 0.8909 - val_loss: 0.4386 - val_binary_accuracy: 0.8114 - val_recall: 0.9271 - val_precision: 0.7601 - val_auc: 0.8611
# Epoch 16/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3918 - binary_accuracy: 0.8346 - recall: 0.9220 - precision: 0.7842 - auc: 0.8939
# Epoch 16: val_binary_accuracy did not improve from 0.81161
# 345/345 [==============================] - 79s 228ms/step - loss: 0.3918 - binary_accuracy: 0.8346 - recall: 0.9220 - precision: 0.7842 - auc: 0.8939 - val_loss: 0.4378 - val_binary_accuracy: 0.8116 - val_recall: 0.9257 - val_precision: 0.7609 - val_auc: 0.8613
# Epoch 17/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3862 - binary_accuracy: 0.8378 - recall: 0.9232 - precision: 0.7878 - auc: 0.8969
# Epoch 17: val_binary_accuracy did not improve from 0.81161
# 345/345 [==============================] - 79s 229ms/step - loss: 0.3862 - binary_accuracy: 0.8378 - recall: 0.9232 - precision: 0.7878 - auc: 0.8969 - val_loss: 0.4378 - val_binary_accuracy: 0.8116 - val_recall: 0.9248 - val_precision: 0.7613 - val_auc: 0.8618
# Epoch 18/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3806 - binary_accuracy: 0.8404 - recall: 0.9241 - precision: 0.7909 - auc: 0.9001
# Epoch 18: val_binary_accuracy improved from 0.81161 to 0.81185, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 228ms/step - loss: 0.3806 - binary_accuracy: 0.8404 - recall: 0.9241 - precision: 0.7909 - auc: 0.9001 - val_loss: 0.4375 - val_binary_accuracy: 0.8118 - val_recall: 0.9244 - val_precision: 0.7618 - val_auc: 0.8624
# Epoch 19/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3750 - binary_accuracy: 0.8435 - recall: 0.9248 - precision: 0.7949 - auc: 0.9034
# Epoch 19: val_binary_accuracy improved from 0.81185 to 0.81278, saving model to ./Models/A\best_model.keras
# 345/345 [==============================] - 79s 229ms/step - loss: 0.3750 - binary_accuracy: 0.8435 - recall: 0.9248 - precision: 0.7949 - auc: 0.9034 - val_loss: 0.4371 - val_binary_accuracy: 0.8128 - val_recall: 0.9235 - val_precision: 0.7633 - val_auc: 0.8631
# Epoch 20/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3694 - binary_accuracy: 0.8464 - recall: 0.9248 - precision: 0.7988 - auc: 0.9068
# Epoch 20: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.3694 - binary_accuracy: 0.8464 - recall: 0.9248 - precision: 0.7988 - auc: 0.9068 - val_loss: 0.4368 - val_binary_accuracy: 0.8125 - val_recall: 0.9208 - val_precision: 0.7642 - val_auc: 0.8654
# Epoch 21/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3636 - binary_accuracy: 0.8504 - recall: 0.9267 - precision: 0.8034 - auc: 0.9099
# Epoch 21: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.3636 - binary_accuracy: 0.8504 - recall: 0.9267 - precision: 0.8034 - auc: 0.9099 - val_loss: 0.4366 - val_binary_accuracy: 0.8118 - val_recall: 0.9185 - val_precision: 0.7643 - val_auc: 0.8661
# Epoch 22/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3579 - binary_accuracy: 0.8538 - recall: 0.9276 - precision: 0.8077 - auc: 0.9128
# Epoch 22: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.3579 - binary_accuracy: 0.8538 - recall: 0.9276 - precision: 0.8077 - auc: 0.9128 - val_loss: 0.4361 - val_binary_accuracy: 0.8107 - val_recall: 0.9127 - val_precision: 0.7655 - val_auc: 0.8662
# Epoch 23/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3518 - binary_accuracy: 0.8579 - recall: 0.9292 - precision: 0.8125 - auc: 0.9160
# Epoch 23: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.3518 - binary_accuracy: 0.8579 - recall: 0.9292 - precision: 0.8125 - auc: 0.9160 - val_loss: 0.4360 - val_binary_accuracy: 0.8111 - val_recall: 0.9090 - val_precision: 0.7677 - val_auc: 0.8665
# Epoch 24/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3457 - binary_accuracy: 0.8608 - recall: 0.9298 - precision: 0.8164 - auc: 0.9190
# Epoch 24: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.3457 - binary_accuracy: 0.8608 - recall: 0.9298 - precision: 0.8164 - auc: 0.9190 - val_loss: 0.4363 - val_binary_accuracy: 0.8088 - val_recall: 0.9045 - val_precision: 0.7668 - val_auc: 0.8671
# Epoch 25/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3393 - binary_accuracy: 0.8648 - recall: 0.9315 - precision: 0.8213 - auc: 0.9223
# Epoch 25: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.3393 - binary_accuracy: 0.8648 - recall: 0.9315 - precision: 0.8213 - auc: 0.9223 - val_loss: 0.4367 - val_binary_accuracy: 0.8088 - val_recall: 0.9018 - val_precision: 0.7680 - val_auc: 0.8675
# Epoch 26/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3327 - binary_accuracy: 0.8684 - recall: 0.9327 - precision: 0.8258 - auc: 0.9256
# Epoch 26: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.3327 - binary_accuracy: 0.8684 - recall: 0.9327 - precision: 0.8258 - auc: 0.9256 - val_loss: 0.4373 - val_binary_accuracy: 0.8088 - val_recall: 0.9009 - val_precision: 0.7684 - val_auc: 0.8675
# Epoch 27/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3260 - binary_accuracy: 0.8721 - recall: 0.9344 - precision: 0.8303 - auc: 0.9288
# Epoch 27: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.3260 - binary_accuracy: 0.8721 - recall: 0.9344 - precision: 0.8303 - auc: 0.9288 - val_loss: 0.4386 - val_binary_accuracy: 0.8079 - val_recall: 0.8982 - val_precision: 0.7685 - val_auc: 0.8675
# Epoch 28/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3190 - binary_accuracy: 0.8757 - recall: 0.9355 - precision: 0.8351 - auc: 0.9319
# Epoch 28: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.3190 - binary_accuracy: 0.8757 - recall: 0.9355 - precision: 0.8351 - auc: 0.9319 - val_loss: 0.4399 - val_binary_accuracy: 0.8077 - val_recall: 0.8960 - val_precision: 0.7692 - val_auc: 0.8674
# Epoch 29/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3120 - binary_accuracy: 0.8792 - recall: 0.9370 - precision: 0.8393 - auc: 0.9351
# Epoch 29: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 230ms/step - loss: 0.3120 - binary_accuracy: 0.8792 - recall: 0.9370 - precision: 0.8393 - auc: 0.9351 - val_loss: 0.4411 - val_binary_accuracy: 0.8102 - val_recall: 0.8951 - val_precision: 0.7729 - val_auc: 0.8667
# Epoch 30/50
# 345/345 [==============================] - ETA: 0s - loss: 0.3045 - binary_accuracy: 0.8835 - recall: 0.9395 - precision: 0.8443 - auc: 0.9385
# Epoch 30: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.3045 - binary_accuracy: 0.8835 - recall: 0.9395 - precision: 0.8443 - auc: 0.9385 - val_loss: 0.4426 - val_binary_accuracy: 0.8093 - val_recall: 0.8906 - val_precision: 0.7739 - val_auc: 0.8671
# Epoch 31/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2968 - binary_accuracy: 0.8875 - recall: 0.9414 - precision: 0.8492 - auc: 0.9417
# Epoch 31: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.2968 - binary_accuracy: 0.8875 - recall: 0.9414 - precision: 0.8492 - auc: 0.9417 - val_loss: 0.4438 - val_binary_accuracy: 0.8109 - val_recall: 0.8897 - val_precision: 0.7764 - val_auc: 0.8673
# Epoch 32/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2890 - binary_accuracy: 0.8927 - recall: 0.9442 - precision: 0.8555 - auc: 0.9450
# Epoch 32: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.2890 - binary_accuracy: 0.8927 - recall: 0.9442 - precision: 0.8555 - auc: 0.9450 - val_loss: 0.4459 - val_binary_accuracy: 0.8107 - val_recall: 0.8865 - val_precision: 0.7776 - val_auc: 0.8681
# Epoch 33/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2807 - binary_accuracy: 0.8973 - recall: 0.9464 - precision: 0.8612 - auc: 0.9483
# Epoch 33: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 80s 230ms/step - loss: 0.2807 - binary_accuracy: 0.8973 - recall: 0.9464 - precision: 0.8612 - auc: 0.9483 - val_loss: 0.4478 - val_binary_accuracy: 0.8095 - val_recall: 0.8834 - val_precision: 0.7776 - val_auc: 0.8686
# Epoch 34/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2722 - binary_accuracy: 0.9017 - recall: 0.9486 - precision: 0.8667 - auc: 0.9515
# Epoch 34: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.2722 - binary_accuracy: 0.9017 - recall: 0.9486 - precision: 0.8667 - auc: 0.9515 - val_loss: 0.4498 - val_binary_accuracy: 0.8088 - val_recall: 0.8816 - val_precision: 0.7776 - val_auc: 0.8684
# Epoch 35/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2635 - binary_accuracy: 0.9068 - recall: 0.9515 - precision: 0.8730 - auc: 0.9548
# Epoch 35: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.2635 - binary_accuracy: 0.9068 - recall: 0.9515 - precision: 0.8730 - auc: 0.9548 - val_loss: 0.4527 - val_binary_accuracy: 0.8067 - val_recall: 0.8784 - val_precision: 0.7764 - val_auc: 0.8682
# Epoch 36/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2543 - binary_accuracy: 0.9120 - recall: 0.9542 - precision: 0.8794 - auc: 0.9580
# Epoch 36: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.2543 - binary_accuracy: 0.9120 - recall: 0.9542 - precision: 0.8794 - auc: 0.9580 - val_loss: 0.4551 - val_binary_accuracy: 0.8067 - val_recall: 0.8739 - val_precision: 0.7786 - val_auc: 0.8680
# Epoch 37/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2449 - binary_accuracy: 0.9174 - recall: 0.9566 - precision: 0.8867 - auc: 0.9614
# Epoch 37: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 230ms/step - loss: 0.2449 - binary_accuracy: 0.9174 - recall: 0.9566 - precision: 0.8867 - auc: 0.9614 - val_loss: 0.4582 - val_binary_accuracy: 0.8067 - val_recall: 0.8726 - val_precision: 0.7793 - val_auc: 0.8688
# Epoch 38/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2352 - binary_accuracy: 0.9222 - recall: 0.9590 - precision: 0.8929 - auc: 0.9645
# Epoch 38: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.2352 - binary_accuracy: 0.9222 - recall: 0.9590 - precision: 0.8929 - auc: 0.9645 - val_loss: 0.4610 - val_binary_accuracy: 0.8077 - val_recall: 0.8703 - val_precision: 0.7816 - val_auc: 0.8682
# Epoch 39/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2255 - binary_accuracy: 0.9276 - recall: 0.9622 - precision: 0.8995 - auc: 0.9675
# Epoch 39: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 78s 227ms/step - loss: 0.2255 - binary_accuracy: 0.9276 - recall: 0.9622 - precision: 0.8995 - auc: 0.9675 - val_loss: 0.4647 - val_binary_accuracy: 0.8070 - val_recall: 0.8676 - val_precision: 0.7821 - val_auc: 0.8679
# Epoch 40/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2153 - binary_accuracy: 0.9323 - recall: 0.9646 - precision: 0.9057 - auc: 0.9704
# Epoch 40: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.2153 - binary_accuracy: 0.9323 - recall: 0.9646 - precision: 0.9057 - auc: 0.9704 - val_loss: 0.4685 - val_binary_accuracy: 0.8046 - val_recall: 0.8600 - val_precision: 0.7828 - val_auc: 0.8674
# Epoch 41/50
# 345/345 [==============================] - ETA: 0s - loss: 0.2051 - binary_accuracy: 0.9375 - recall: 0.9672 - precision: 0.9127 - auc: 0.9732
# Epoch 41: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.2051 - binary_accuracy: 0.9375 - recall: 0.9672 - precision: 0.9127 - auc: 0.9732 - val_loss: 0.4731 - val_binary_accuracy: 0.8026 - val_recall: 0.8514 - val_precision: 0.7843 - val_auc: 0.8671
# Epoch 42/50
# 345/345 [==============================] - ETA: 0s - loss: 0.1949 - binary_accuracy: 0.9427 - recall: 0.9693 - precision: 0.9201 - auc: 0.9757
# Epoch 42: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.1949 - binary_accuracy: 0.9427 - recall: 0.9693 - precision: 0.9201 - auc: 0.9757 - val_loss: 0.4784 - val_binary_accuracy: 0.8028 - val_recall: 0.8469 - val_precision: 0.7870 - val_auc: 0.8660
# Epoch 43/50
# 345/345 [==============================] - ETA: 0s - loss: 0.1846 - binary_accuracy: 0.9483 - recall: 0.9721 - precision: 0.9276 - auc: 0.9780
# Epoch 43: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.1846 - binary_accuracy: 0.9483 - recall: 0.9721 - precision: 0.9276 - auc: 0.9780 - val_loss: 0.4842 - val_binary_accuracy: 0.8012 - val_recall: 0.8366 - val_precision: 0.7903 - val_auc: 0.8645
# Epoch 44/50
# 345/345 [==============================] - ETA: 0s - loss: 0.1744 - binary_accuracy: 0.9522 - recall: 0.9739 - precision: 0.9330 - auc: 0.9802
# Epoch 44: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.1744 - binary_accuracy: 0.9522 - recall: 0.9739 - precision: 0.9330 - auc: 0.9802 - val_loss: 0.4904 - val_binary_accuracy: 0.7993 - val_recall: 0.8321 - val_precision: 0.7901 - val_auc: 0.8640
# Epoch 45/50
# 345/345 [==============================] - ETA: 0s - loss: 0.1646 - binary_accuracy: 0.9561 - recall: 0.9755 - precision: 0.9389 - auc: 0.9822
# Epoch 45: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.1646 - binary_accuracy: 0.9561 - recall: 0.9755 - precision: 0.9389 - auc: 0.9822 - val_loss: 0.4990 - val_binary_accuracy: 0.7949 - val_recall: 0.8172 - val_precision: 0.7919 - val_auc: 0.8625
# Epoch 46/50
# 345/345 [==============================] - ETA: 0s - loss: 0.1558 - binary_accuracy: 0.9598 - recall: 0.9766 - precision: 0.9447 - auc: 0.9838
# Epoch 46: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.1558 - binary_accuracy: 0.9598 - recall: 0.9766 - precision: 0.9447 - auc: 0.9838 - val_loss: 0.5050 - val_binary_accuracy: 0.7944 - val_recall: 0.8167 - val_precision: 0.7914 - val_auc: 0.8620
# Epoch 47/50
# 345/345 [==============================] - ETA: 0s - loss: 0.1484 - binary_accuracy: 0.9618 - recall: 0.9770 - precision: 0.9479 - auc: 0.9851
# Epoch 47: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.1484 - binary_accuracy: 0.9618 - recall: 0.9770 - precision: 0.9479 - auc: 0.9851 - val_loss: 0.5112 - val_binary_accuracy: 0.7967 - val_recall: 0.8352 - val_precision: 0.7847 - val_auc: 0.8601
# Epoch 48/50
# 345/345 [==============================] - ETA: 0s - loss: 0.1424 - binary_accuracy: 0.9639 - recall: 0.9773 - precision: 0.9516 - auc: 0.9862
# Epoch 48: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.1424 - binary_accuracy: 0.9639 - recall: 0.9773 - precision: 0.9516 - auc: 0.9862 - val_loss: 0.5199 - val_binary_accuracy: 0.7984 - val_recall: 0.8546 - val_precision: 0.7769 - val_auc: 0.8594
# Epoch 49/50
# 345/345 [==============================] - ETA: 0s - loss: 0.1374 - binary_accuracy: 0.9652 - recall: 0.9776 - precision: 0.9539 - auc: 0.9872
# Epoch 49: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 229ms/step - loss: 0.1374 - binary_accuracy: 0.9652 - recall: 0.9776 - precision: 0.9539 - auc: 0.9872 - val_loss: 0.5251 - val_binary_accuracy: 0.7914 - val_recall: 0.8339 - val_precision: 0.7778 - val_auc: 0.8583
# Epoch 50/50
# 345/345 [==============================] - ETA: 0s - loss: 0.1334 - binary_accuracy: 0.9659 - recall: 0.9768 - precision: 0.9558 - auc: 0.9879
# Epoch 50: val_binary_accuracy did not improve from 0.81278
# 345/345 [==============================] - 79s 228ms/step - loss: 0.1334 - binary_accuracy: 0.9659 - recall: 0.9768 - precision: 0.9558 - auc: 0.9879 - val_loss: 0.5333 - val_binary_accuracy: 0.7940 - val_recall: 0.8505 - val_precision: 0.7729 - val_auc: 0.8573
