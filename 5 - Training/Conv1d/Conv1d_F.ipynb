# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
path = "/content/drive/MyDrive/TFM/"
path1 = path + "Planets.csv"
path2 = path + "Not_Planets.csv"

# %%
#Creación del dataset con los registros de secuencias positivas y secuencias negativas
planets_df = pd.read_csv(path1, names=list(range(4000)))
not_planets_df = pd.read_csv(path2, names=list(range(4000)))
X_data = pd.concat([planets_df, not_planets_df]).to_numpy()
y_data = np.concatenate((np.ones(len(planets_df)), np.zeros(len(not_planets_df))))

#Separación en train y test
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.20, random_state=42)
y_train = np.transpose(np.atleast_2d(y_train))
y_test = np.transpose(np.atleast_2d(y_test))

# %%
#Definición del modelo a entrenar
from tensorflow.keras import layers
from tensorflow import keras

model_name = "Conv1D_F"

model = keras.Sequential(
    [
        layers.Input(shape=(4000,1)),
        layers.Conv1D(filters=32, kernel_size=100, activation='relu'),
        layers.MaxPooling1D(pool_size=3),
        layers.Conv1D(filters=64, kernel_size=100, activation='relu'),
        layers.MaxPooling1D(pool_size=3),
        layers.Conv1D(filters=128, kernel_size=100, activation='relu'),
        layers.MaxPooling1D(pool_size=3),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(100, activation='sigmoid'),
        layers.Dense(1, activation='sigmoid')
    ],
    name=model_name
)

# %%
from datetime import datetime
#Compilación del modelo
model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=[
              keras.metrics.BinaryAccuracy(),
              keras.metrics.Recall(),
              keras.metrics.Precision(),
              keras.metrics.AUC(num_thresholds=25)
            ]
    )

#Definición del directorio donde guardar los datos del entrenamiento
logdir = "/content/drive/MyDrive/TFM/Logs/" + model.name + "/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/TFM/Models/" + model_name + "/best_model.keras",
    verbose=1,
    save_best_only=True,
    mode="max",
    monitor="val_binary_accuracy",
)

# %%
training_history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    verbose=1, # Suppress chatty output; use Tensorboard instead
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=[tensorboard_callback, model_checkpoint],
)
# Out:
# Epoch 1/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - auc: 0.5906 - binary_accuracy: 0.5792 - loss: 0.6700 - precision: 0.5646 - recall: 0.8223
# Epoch 1: val_binary_accuracy improved from -inf to 0.63581, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_F/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 48s 76ms/step - auc: 0.5907 - binary_accuracy: 0.5792 - loss: 0.6700 - precision: 0.5646 - recall: 0.8224 - val_auc: 0.6183 - val_binary_accuracy: 0.6358 - val_loss: 0.6402 - val_precision: 0.5956 - val_recall: 0.9660
# Epoch 2/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - auc: 0.6001 - binary_accuracy: 0.6137 - loss: 0.6375 - precision: 0.5783 - recall: 0.9394
# Epoch 2: val_binary_accuracy improved from 0.63581 to 0.64411, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_F/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 69s 63ms/step - auc: 0.6002 - binary_accuracy: 0.6137 - loss: 0.6375 - precision: 0.5783 - recall: 0.9394 - val_auc: 0.6354 - val_binary_accuracy: 0.6441 - val_loss: 0.6248 - val_precision: 0.6042 - val_recall: 0.9443
# Epoch 3/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - auc: 0.6601 - binary_accuracy: 0.6564 - loss: 0.6065 - precision: 0.6119 - recall: 0.9187
# Epoch 3: val_binary_accuracy improved from 0.64411 to 0.65856, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_F/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 41s 62ms/step - auc: 0.6601 - binary_accuracy: 0.6564 - loss: 0.6065 - precision: 0.6119 - recall: 0.9187 - val_auc: 0.6950 - val_binary_accuracy: 0.6586 - val_loss: 0.5987 - val_precision: 0.6469 - val_recall: 0.7776
# Epoch 4/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - auc: 0.6804 - binary_accuracy: 0.6629 - loss: 0.5985 - precision: 0.6170 - recall: 0.9072
# Epoch 4: val_binary_accuracy improved from 0.65856 to 0.66602, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_F/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 42s 64ms/step - auc: 0.6804 - binary_accuracy: 0.6629 - loss: 0.5985 - precision: 0.6170 - recall: 0.9072 - val_auc: 0.7113 - val_binary_accuracy: 0.6660 - val_loss: 0.5898 - val_precision: 0.6577 - val_recall: 0.7660
# Epoch 5/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - auc: 0.7005 - binary_accuracy: 0.6794 - loss: 0.5783 - precision: 0.6288 - recall: 0.9207
# Epoch 5: val_binary_accuracy improved from 0.66602 to 0.68974, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_F/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - auc: 0.7005 - binary_accuracy: 0.6794 - loss: 0.5783 - precision: 0.6288 - recall: 0.9207 - val_auc: 0.7154 - val_binary_accuracy: 0.6897 - val_loss: 0.5727 - val_precision: 0.6393 - val_recall: 0.9457
# Epoch 6/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - auc: 0.7258 - binary_accuracy: 0.6930 - loss: 0.5658 - precision: 0.6424 - recall: 0.9180
# Epoch 6: val_binary_accuracy improved from 0.68974 to 0.70720, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_F/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 40s 63ms/step - auc: 0.7258 - binary_accuracy: 0.6930 - loss: 0.5658 - precision: 0.6424 - recall: 0.9180 - val_auc: 0.7359 - val_binary_accuracy: 0.7072 - val_loss: 0.5554 - val_precision: 0.6514 - val_recall: 0.9578
# Epoch 7/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - auc: 0.7448 - binary_accuracy: 0.7030 - loss: 0.5534 - precision: 0.6509 - recall: 0.9172
# Epoch 7: val_binary_accuracy improved from 0.70720 to 0.71153, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_F/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 41s 63ms/step - auc: 0.7448 - binary_accuracy: 0.7030 - loss: 0.5534 - precision: 0.6508 - recall: 0.9172 - val_auc: 0.7517 - val_binary_accuracy: 0.7115 - val_loss: 0.5504 - val_precision: 0.6686 - val_recall: 0.8992
# Epoch 8/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - auc: 0.7434 - binary_accuracy: 0.6984 - loss: 0.5565 - precision: 0.6456 - recall: 0.9143
# Epoch 8: val_binary_accuracy did not improve from 0.71153
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 41s 62ms/step - auc: 0.7434 - binary_accuracy: 0.6984 - loss: 0.5565 - precision: 0.6457 - recall: 0.9143 - val_auc: 0.7476 - val_binary_accuracy: 0.7101 - val_loss: 0.5604 - val_precision: 0.6652 - val_recall: 0.9076
# Epoch 9/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - auc: 0.7497 - binary_accuracy: 0.7074 - loss: 0.5525 - precision: 0.6592 - recall: 0.9105
# Epoch 9: val_binary_accuracy improved from 0.71153 to 0.71418, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_F/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 41s 63ms/step - auc: 0.7497 - binary_accuracy: 0.7074 - loss: 0.5525 - precision: 0.6592 - recall: 0.9104 - val_auc: 0.7556 - val_binary_accuracy: 0.7142 - val_loss: 0.5434 - val_precision: 0.6657 - val_recall: 0.9211
# Epoch 10/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - auc: 0.7557 - binary_accuracy: 0.7082 - loss: 0.5478 - precision: 0.6589 - recall: 0.9022
# Epoch 10: val_binary_accuracy did not improve from 0.71418
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 32s 62ms/step - auc: 0.7557 - binary_accuracy: 0.7082 - loss: 0.5478 - precision: 0.6589 - recall: 0.9022 - val_auc: 0.7582 - val_binary_accuracy: 0.6911 - val_loss: 0.5568 - val_precision: 0.6866 - val_recall: 0.7630
# Epoch 11/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - auc: 0