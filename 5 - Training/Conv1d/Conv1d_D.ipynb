# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
path = "/content/drive/MyDrive/TFM/"
path1 = path + "Planets.csv"
path2 = path + "Not_Planets.csv"

# %%
#Creación del dataset con los registros de secuencias positivas y secuencias negativas
planets_df = pd.read_csv(path1, names=list(range(4000)))
not_planets_df = pd.read_csv(path2, names=list(range(4000)))
X_data = pd.concat([planets_df, not_planets_df]).to_numpy()
y_data = np.concatenate((np.ones(len(planets_df)), np.zeros(len(not_planets_df))))

#Separación en train y test
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.20, random_state=42)
y_train = np.transpose(np.atleast_2d(y_train))
y_test = np.transpose(np.atleast_2d(y_test))

# %%
#Definición del modelo a entrenar
from tensorflow.keras import layers
from tensorflow import keras

model_name = "Conv1D_D"

model = keras.Sequential(
    [
        layers.Input(shape=(4000,1)),
        layers.Conv1D(filters=64, kernel_size=5, activation='relu'),
        layers.MaxPooling1D(pool_size=3),
        layers.Conv1D(filters=64, kernel_size=5, activation='relu'),
        layers.MaxPooling1D(pool_size=3),
        layers.Conv1D(filters=64, kernel_size=5, activation='relu'),
        layers.MaxPooling1D(pool_size=3),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(100, activation='sigmoid'),
        layers.Dense(1, activation='sigmoid')
    ],
    name=model_name
)

# %%
from datetime import datetime
#Compilación del modelo
model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=[
              keras.metrics.BinaryAccuracy(),
              keras.metrics.Recall(),
              keras.metrics.Precision(),
              keras.metrics.AUC(num_thresholds=25)
            ]
    )

#Definición del directorio donde guardar los datos del entrenamiento
logdir = "/content/drive/MyDrive/TFM/Logs/" + model.name + "/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/TFM/Models/" + model_name + "/best_model.keras",
    verbose=1,
    save_best_only=True,
    mode="max",
    monitor="val_binary_accuracy",
)

# %%
training_history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    verbose=1, # Suppress chatty output; use Tensorboard instead
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=[tensorboard_callback, model_checkpoint],
)
# Out:
# Epoch 1/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - auc: 0.5711 - binary_accuracy: 0.5695 - loss: 0.6655 - precision: 0.5523 - recall: 0.8251
# Epoch 1: val_binary_accuracy improved from -inf to 0.61064, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 32s 47ms/step - auc: 0.5711 - binary_accuracy: 0.5695 - loss: 0.6654 - precision: 0.5523 - recall: 0.8252 - val_auc: 0.6241 - val_binary_accuracy: 0.6106 - val_loss: 0.6403 - val_precision: 0.5787 - val_recall: 0.9640
# Epoch 2/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - auc: 0.6601 - binary_accuracy: 0.6454 - loss: 0.6178 - precision: 0.6063 - recall: 0.8920
# Epoch 2: val_binary_accuracy improved from 0.61064 to 0.68131, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - auc: 0.6601 - binary_accuracy: 0.6454 - loss: 0.6178 - precision: 0.6063 - recall: 0.8920 - val_auc: 0.7032 - val_binary_accuracy: 0.6813 - val_loss: 0.5912 - val_precision: 0.6280 - val_recall: 0.9717
# Epoch 3/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - auc: 0.7097 - binary_accuracy: 0.6813 - loss: 0.5805 - precision: 0.6346 - recall: 0.8841
# Epoch 3: val_binary_accuracy did not improve from 0.68131
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - auc: 0.7098 - binary_accuracy: 0.6813 - loss: 0.5805 - precision: 0.6347 - recall: 0.8841 - val_auc: 0.7113 - val_binary_accuracy: 0.6811 - val_loss: 0.5963 - val_precision: 0.6274 - val_recall: 0.9742
# Epoch 4/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.7158 - binary_accuracy: 0.6847 - loss: 0.5793 - precision: 0.6399 - recall: 0.8821
# Epoch 4: val_binary_accuracy improved from 0.68131 to 0.70720, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - auc: 0.7158 - binary_accuracy: 0.6847 - loss: 0.5792 - precision: 0.6399 - recall: 0.8821 - val_auc: 0.7450 - val_binary_accuracy: 0.7072 - val_loss: 0.5569 - val_precision: 0.6560 - val_recall: 0.9361
# Epoch 5/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.7514 - binary_accuracy: 0.7081 - loss: 0.5503 - precision: 0.6627 - recall: 0.8911
# Epoch 5: val_binary_accuracy improved from 0.70720 to 0.71755, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - auc: 0.7514 - binary_accuracy: 0.7081 - loss: 0.5503 - precision: 0.6626 - recall: 0.8911 - val_auc: 0.7529 - val_binary_accuracy: 0.7176 - val_loss: 0.5484 - val_precision: 0.6837 - val_recall: 0.8650
# Epoch 6/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.7699 - binary_accuracy: 0.7158 - loss: 0.5378 - precision: 0.6683 - recall: 0.8844
# Epoch 6: val_binary_accuracy improved from 0.71755 to 0.72610, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - auc: 0.7699 - binary_accuracy: 0.7158 - loss: 0.5378 - precision: 0.6684 - recall: 0.8844 - val_auc: 0.7697 - val_binary_accuracy: 0.7261 - val_loss: 0.5385 - val_precision: 0.6797 - val_recall: 0.9097
# Epoch 7/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.7765 - binary_accuracy: 0.7205 - loss: 0.5328 - precision: 0.6744 - recall: 0.8837
# Epoch 7: val_binary_accuracy improved from 0.72610 to 0.73802, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - auc: 0.7765 - binary_accuracy: 0.7205 - loss: 0.5328 - precision: 0.6745 - recall: 0.8837 - val_auc: 0.7755 - val_binary_accuracy: 0.7380 - val_loss: 0.5308 - val_precision: 0.6996 - val_recall: 0.8825
# Epoch 8/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.7899 - binary_accuracy: 0.7299 - loss: 0.5223 - precision: 0.6830 - recall: 0.8766
# Epoch 8: val_binary_accuracy did not improve from 0.73802
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - auc: 0.7899 - binary_accuracy: 0.7300 - loss: 0.5223 - precision: 0.6831 - recall: 0.8767 - val_auc: 0.7673 - val_binary_accuracy: 0.7245 - val_loss: 0.5463 - val_precision: 0.6744 - val_recall: 0.9243
# Epoch 9/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.8039 - binary_accuracy: 0.7437 - loss: 0.5069 - precision: 0.6958 - recall: 0.8943
# Epoch 9: val_binary_accuracy improved from 0.73802 to 0.74669, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - auc: 0.8039 - binary_accuracy: 0.7437 - loss: 0.5069 - precision: 0.6958 - recall: 0.8943 - val_auc: 0.7954 - val_binary_accuracy: 0.7467 - val_loss: 0.5218 - val_precision: 0.7054 - val_recall: 0.8930
# Epoch 10/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.8121 - binary_accuracy: 0.7479 - loss: 0.4991 - precision: 0.7028 - recall: 0.8901
# Epoch 10: val_binary_accuracy improved from 0.74669 to 0.74958, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - auc: 0.8121 - binary_accuracy: 0.7479 - loss: 0.4991 - precision: 0.7028 - recall: 0.8901 - val_auc: 0.7998 - val_binary_accuracy: 0.7496 - val_loss: 0.5179 - val_precision: 0.7231 - val_recall: 0.8517
# Epoch 11/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.8268 - binary_accuracy: 0.7609 - loss: 0.4841 - precision: 0.7138 - recall: 0.9012
# Epoch 11: val_binary_accuracy improved from 0.74958 to 0.75451, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - auc: 0.8269 - binary_accuracy: 0.7609 - loss: 0.4841 - precision: 0.7138 - recall: 0.9012 - val_auc: 0.8032 - val_binary_accuracy: 0.7545 - val_loss: 0.5104 - val_precision: 0.7179 - val_recall: 0.8812
# Epoch 12/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.8378 - binary_accuracy: 0.7681 - loss: 0.4735 - precision: 0.7219 - recall: 0.8971
# Epoch 12: val_binary_accuracy improved from 0.75451 to 0.75765, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - auc: 0.8378 - binary_accuracy: 0.7681 - loss: 0.4735 - precision: 0.7219 - recall: 0.8971 - val_auc: 0.8030 - val_binary_accuracy: 0.7576 - val_loss: 0.5120 - val_precision: 0.7156 - val_recall: 0.8976
# Epoch 13/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.8431 - binary_accuracy: 0.7690 - loss: 0.4675 - precision: 0.7234 - recall: 0.8930
# Epoch 13: val_binary_accuracy did not improve from 0.75765
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - auc: 0.8431 - binary_accuracy: 0.7690 - loss: 0.4675 - precision: 0.7234 - recall: 0.8930 - val_auc: 0.8125 - val_binary_accuracy: 0.7525 - val_loss: 0.5090 - val_precision: 0.7027 - val_recall: 0.9204
# Epoch 14/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - auc: 0.8523 - binary_accuracy: 0.7781 - loss: 0.4551 - precision: 0.7340 - recall: 0.9042
# Epoch 14: val_binary_accuracy did not improve from 0.75765
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - auc: 0.8523 - binary_accuracy: 0.7781 - loss: 0.4551 - precision: 0.7340 - recall: 0.9042 - val_auc: 0.8078 - val_binary_accuracy: 0.7477 - val_loss: 0.5147 - val_precision: 0.7178 - val_recall: 0.8599
# Epoch 15/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.8534 - binary_accuracy: 0.7756 - loss: 0.4550 - precision: 0.7331 - recall: 0.8918
# Epoch 15: val_binary_accuracy did not improve from 0.75765
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - auc: 0.8534 - binary_accuracy: 0.7756 - loss: 0.4550 - precision: 0.7331 - recall: 0.8918 - val_auc: 0.8074 - val_binary_accuracy: 0.7486 - val_loss: 0.5150 - val_precision: 0.7312 - val_recall: 0.8282
# Epoch 16/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - auc: 0.8662 - binary_accuracy: 0.7883 - loss: 0.4387 - precision: 0.7466 - recall: 0.8938
# Epoch 16: val_binary_accuracy improved from 0.75765 to 0.76463, saving model to /content/drive/MyDrive/TFM/Models/Conv1D_D/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - auc: 0.8662 - binary_accuracy: 0.7883 - loss: 0.4387 - precision: 0.7465 - recall: 0.8938 - val_auc: 0.8148 - val_binary_accuracy: 0.7646 - val_loss: 0.5151 - val_precision: 0.7137 - val_recall: 0.9252
# Epoch 17/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.8700 - binary_accuracy: 0.7911 - loss: 0.4324 - precision: 0.7476 - recall: 0.8999
# Epoch 17: val_binary_accuracy did not improve from 0.76463
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - auc: 0.8700 - binary_accuracy: 0.7911 - loss: 0.4324 - precision: 0.7476 - recall: 0.8999 - val_auc: 0.8042 - val_binary_accuracy: 0.7124 - val_loss: 0.5439 - val_precision: 0.7456 - val_recall: 0.6907
# Epoch 18/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step