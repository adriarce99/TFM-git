# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
path = "/content/drive/MyDrive/TFM/"
path1 = path + "Planets.csv"
path2 = path + "Not_Planets.csv"

# %%
#Creación del dataset con los registros de secuencias positivas y secuencias negativas
planets_df = pd.read_csv(path1, names=list(range(4000)))
not_planets_df = pd.read_csv(path2, names=list(range(4000)))
X_data = pd.concat([planets_df, not_planets_df]).to_numpy()
y_data = np.concatenate((np.ones(len(planets_df)), np.zeros(len(not_planets_df))))

#Separación en train y test
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.20, random_state=42)
y_train = np.transpose(np.atleast_2d(y_train))
y_test = np.transpose(np.atleast_2d(y_test))

# %%
#Definición del modelo a entrenar
from tensorflow.keras import layers
from tensorflow import keras

model_name = "Conv2D_H"

model = keras.Sequential(
    [
        layers.Input(shape=(4000,1)),
        layers.Reshape((500,8,1)),
        layers.Conv2D(filters=32, kernel_size=(100,2), activation='relu'),
        layers.MaxPooling2D(pool_size=(3,1)),
        layers.Conv2D(filters=32, kernel_size=(100,2), activation='relu'),
        layers.MaxPooling2D(pool_size=(3,1)),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(100, activation='sigmoid'),
        layers.Dense(1, activation='sigmoid')
    ],
    name=model_name
)

# %%
from datetime import datetime
#Compilación del modelo
model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=[
              keras.metrics.BinaryAccuracy(),
              keras.metrics.Recall(),
              keras.metrics.Precision(),
              keras.metrics.AUC(num_thresholds=25)
            ]
    )

#Definición del directorio donde guardar los datos del entrenamiento
logdir = "/content/drive/MyDrive/TFM/Logs/" + model.name + "/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/TFM/Models/" + model_name + "/best_model.keras",
    verbose=1,
    save_best_only=True,
    mode="max",
    monitor="val_binary_accuracy",
)

# %%
training_history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    verbose=1, # Suppress chatty output; use Tensorboard instead
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=[tensorboard_callback, model_checkpoint],
)
# Out:
# Epoch 1/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.6149 - binary_accuracy: 0.6052 - loss: 0.6440 - precision: 0.5805 - recall: 0.8414
# Epoch 1: val_binary_accuracy improved from -inf to 0.48242, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - auc: 0.6149 - binary_accuracy: 0.6052 - loss: 0.6440 - precision: 0.5806 - recall: 0.8415 - val_auc: 0.6507 - val_binary_accuracy: 0.4824 - val_loss: 0.6888 - val_precision: 0.6261 - val_recall: 0.0481
# Epoch 2/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.6318 - binary_accuracy: 0.6212 - loss: 0.6246 - precision: 0.5844 - recall: 0.8965
# Epoch 2: val_binary_accuracy improved from 0.48242 to 0.66879, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - auc: 0.6319 - binary_accuracy: 0.6213 - loss: 0.6246 - precision: 0.5844 - recall: 0.8966 - val_auc: 0.6658 - val_binary_accuracy: 0.6688 - val_loss: 0.5922 - val_precision: 0.6231 - val_recall: 0.9430
# Epoch 3/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.6613 - binary_accuracy: 0.6600 - loss: 0.5979 - precision: 0.6150 - recall: 0.9352
# Epoch 3: val_binary_accuracy did not improve from 0.66879
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - auc: 0.6613 - binary_accuracy: 0.6600 - loss: 0.5979 - precision: 0.6150 - recall: 0.9352 - val_auc: 0.6850 - val_binary_accuracy: 0.6658 - val_loss: 0.5928 - val_precision: 0.6145 - val_recall: 0.9843
# Epoch 4/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.6909 - binary_accuracy: 0.6650 - loss: 0.5880 - precision: 0.6155 - recall: 0.9264
# Epoch 4: val_binary_accuracy did not improve from 0.66879
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - auc: 0.6909 - binary_accuracy: 0.6650 - loss: 0.5880 - precision: 0.6155 - recall: 0.9264 - val_auc: 0.7172 - val_binary_accuracy: 0.6672 - val_loss: 0.5936 - val_precision: 0.6151 - val_recall: 0.9877
# Epoch 5/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.6904 - binary_accuracy: 0.6624 - loss: 0.5896 - precision: 0.6133 - recall: 0.9276
# Epoch 5: val_binary_accuracy did not improve from 0.66879
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - auc: 0.6905 - binary_accuracy: 0.6625 - loss: 0.5896 - precision: 0.6134 - recall: 0.9275 - val_auc: 0.7005 - val_binary_accuracy: 0.6570 - val_loss: 0.6030 - val_precision: 0.6075 - val_recall: 0.9891
# Epoch 6/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.6984 - binary_accuracy: 0.6634 - loss: 0.5847 - precision: 0.6155 - recall: 0.9191
# Epoch 6: val_binary_accuracy improved from 0.66879 to 0.69059, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - auc: 0.6985 - binary_accuracy: 0.6634 - loss: 0.5847 - precision: 0.6155 - recall: 0.9191 - val_auc: 0.7235 - val_binary_accuracy: 0.6906 - val_loss: 0.5693 - val_precision: 0.6352 - val_recall: 0.9719
# Epoch 7/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7183 - binary_accuracy: 0.6769 - loss: 0.5731 - precision: 0.6257 - recall: 0.9231
# Epoch 7: val_binary_accuracy improved from 0.69059 to 0.70214, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - auc: 0.7184 - binary_accuracy: 0.6769 - loss: 0.5730 - precision: 0.6257 - recall: 0.9231 - val_auc: 0.7423 - val_binary_accuracy: 0.7021 - val_loss: 0.5556 - val_precision: 0.6523 - val_recall: 0.9332
# Epoch 8/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7364 - binary_accuracy: 0.6894 - loss: 0.5610 - precision: 0.6390 - recall: 0.9145
# Epoch 8: val_binary_accuracy improved from 0.70214 to 0.71165, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - auc: 0.7364 - binary_accuracy: 0.6894 - loss: 0.5610 - precision: 0.6390 - recall: 0.9145 - val_auc: 0.7552 - val_binary_accuracy: 0.7117 - val_loss: 0.5481 - val_precision: 0.6552 - val_recall: 0.9576
# Epoch 9/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7455 - binary_accuracy: 0.6978 - loss: 0.5533 - precision: 0.6467 - recall: 0.9066
# Epoch 9: val_binary_accuracy did not improve from 0.71165
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - auc: 0.7455 - binary_accuracy: 0.6979 - loss: 0.5533 - precision: 0.6467 - recall: 0.9066 - val_auc: 0.7353 - val_binary_accuracy: 0.7001 - val_loss: 0.5577 - val_precision: 0.6481 - val_recall: 0.9450
# Epoch 10/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7480 - binary_accuracy: 0.7019 - loss: 0.5504 - precision: 0.6515 - recall: 0.9072
# Epoch 10: val_binary_accuracy improved from 0.71165 to 0.73236, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.7481 - binary_accuracy: 0.7019 - loss: 0.5503 - precision: 0.6515 - recall: 0.9072 - val_auc: 0.7696 - val_binary_accuracy: 0.7324 - val_loss: 0.5304 - val_precision: 0.6736 - val_recall: 0.9564
# Epoch 11/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7592 - binary_accuracy: 0.7129 - loss: 0.5429 - precision: 0.6627 - recall: 0.9126
# Epoch 11: val_binary_accuracy did not improve from 0.73236
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.7592 - binary_accuracy: 0.7129 - loss: 0.5429 - precision: 0.6627 - recall: 0.9126 - val_auc: 0.7486 - val_binary_accuracy: 0.5690 - val_loss: 0.7243 - val_precision: 0.7525 - val_recall: 0.2733
# Epoch 12/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7549 - binary_accuracy: 0.7117 - loss: 0.5439 - precision: 0.6615 - recall: 0.9039
# Epoch 12: val_binary_accuracy did not improve from 0.73236
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.7549 - binary_accuracy: 0.7118 - loss: 0.5438 - precision: 0.6615 - recall: 0.9039 - val_auc: 0.7672 - val_binary_accuracy: 0.6335 - val_loss: 0.5995 - val_precision: 0.7216 - val_recall: 0.4977
# Epoch 13/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7572 - binary_accuracy: 0.7155 - loss: 0.5380 - precision: 0.6670 - recall: 0.9014
# Epoch 13: val_binary_accuracy did not improve from 0.73236
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.7572 - binary_accuracy: 0.7155 - loss: 0.5380 - precision: 0.6670 - recall: 0.9014 - val_auc: 0.7698 - val_binary_accuracy: 0.7194 - val_loss: 0.5361 - val_precision: 0.6986 - val_recall: 0.8237
# Epoch 14/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7627 - binary_accuracy: 0.7170 - loss: 0.5346 - precision: 0.6684 - recall: 0.8954
# Epoch 14: val_binary_accuracy did not improve from 0.73236
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.7627 - binary_accuracy: 0.7170 - loss: 0.5346 - precision: 0.6684 - recall: 0.8954 - val_auc: 0.7679 - val_binary_accuracy: 0.6486 - val_loss: 0.5739 - val_precision: 0.7322 - val_recall: 0.5269
# Epoch 15/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7757 - binary_accuracy: 0.7242 - loss: 0.5241 - precision: 0.6734 - recall: 0.8939
# Epoch 15: val_binary_accuracy did not improve from 0.73236
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.7757 - binary_accuracy: 0.7243 - loss: 0.5241 - precision: 0.6734 - recall: 0.8940 - val_auc: 0.7656 - val_binary_accuracy: 0.7129 - val_loss: 0.5447 - val_precision: 0.6535 - val_recall: 0.9706
# Epoch 16/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.7746 - binary_accuracy: 0.7272 - loss: 0.5239 - precision: 0.6720 - recall: 0.9192
# Epoch 16: val_binary_accuracy did not improve from 0.73236
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.7746 - binary_accuracy: 0.7272 - loss: 0.5239 - precision: 0.6720 - recall: 0.9192 - val_auc: 0.7717 - val_binary_accuracy: 0.7259 - val_loss: 0.5378 - val_precision: 0.6646 - val_recall: 0.9703
# Epoch 17/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7846 - binary_accuracy: 0.7345 - loss: 0.5150 - precision: 0.6810 - recall: 0.9112
# Epoch 17: val_binary_accuracy did not improve from 0.73236
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - auc: 0.7846 - binary_accuracy: 0.7345 - loss: 0.5150 - precision: 0.6809 - recall: 0.9112 - val_auc: 0.7727 - val_binary_accuracy: 0.7171 - val_loss: 0.5344 - val_precision: 0.7030 - val_recall: 0.8034
# Epoch 18/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7926 - binary_accuracy: 0.7396 - loss: 0.5072 - precision: 0.6874 - recall: 0.9072
# Epoch 18: val_binary_accuracy did not improve from 0.73236
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.7926 - binary_accuracy: 0.7396 - loss: 0.5072 - precision: 0.6874 - recall: 0.9072 - val_auc: 0.7755 - val_binary_accuracy: 0.7115 - val_loss: 0.5337 - val_precision: 0.7116 - val_recall: 0.7625
# Epoch 19/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.7956 - binary_accuracy: 0.7448 - loss: 0.5063 - precision: 0.6938 - recall: 0.9119
# Epoch 19: val_binary_accuracy improved from 0.73236 to 0.74163, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - auc: 0.7956 - binary_accuracy: 0.7448 - loss: 0.5063 - precision: 0.6938 - recall: 0.9119 - val_auc: 0.7779 - val_binary_accuracy: 0.7416 - val_loss: 0.5248 - val_precision: 0.6919 - val_recall: 0.9202
# Epoch 20/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7921 - binary_accuracy: 0.7390 - loss: 0.5097 - precision: 0.6867 - recall: 0.9112
# Epoch 20: val_binary_accuracy did not improve from 0.74163
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - auc: 0.7921 - binary_accuracy: 0.7390 - loss: 0.5097 - precision: 0.6867 - recall: 0.9112 - val_auc: 0.7755 - val_binary_accuracy: 0.7410 - val_loss: 0.5260 - val_precision: 0.6828 - val_recall: 0.9514
# Epoch 21/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.7939 - binary_accuracy: 0.7431 - loss: 0.5035 - precision: 0.6865 - recall: 0.9151
# Epoch 21: val_binary_accuracy did not improve from 0.74163
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.7938 - binary_accuracy: 0.7431 - loss: 0.5035 - precision: 0.6865 - recall: 0.9151 - val_auc: 0.7713 - val_binary_accuracy: 0.7381 - val_loss: 0.5382 - val_precision: 0.6931 - val_recall: 0.9042
# Epoch 22/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8032 - binary_accuracy: 0.7490 - loss: 0.4952 - precision: 0.6950 - recall: 0.9137
# Epoch 22: val_binary_accuracy did not improve from 0.74163
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - auc: 0.8032 - binary_accuracy: 0.7489 - loss: 0.4952 - precision: 0.6950 - recall: 0.9137 - val_auc: 0.7751 - val_binary_accuracy: 0.7327 - val_loss: 0.5432 - val_precision: 0.6707 - val_recall: 0.9697
# Epoch 23/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8015 - binary_accuracy: 0.7455 - loss: 0.4977 - precision: 0.6917 - recall: 0.9148
# Epoch 23: val_binary_accuracy did not improve from 0.74163
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - auc: 0.8015 - binary_accuracy: 0.7455 - loss: 0.4977 - precision: 0.6917 - recall: 0.9148 - val_auc: 0.7788 - val_binary_accuracy: 0.7295 - val_loss: 0.5335 - val_precision: 0.7115 - val_recall: 0.8198
# Epoch 24/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8102 - binary_accuracy: 0.7534 - loss: 0.4903 - precision: 0.7001 - recall: 0.9180
# Epoch 24: val_binary_accuracy improved from 0.74163 to 0.74801, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.8102 - binary_accuracy: 0.7534 - loss: 0.4903 - precision: 0.7001 - recall: 0.9180 - val_auc: 0.7826 - val_binary_accuracy: 0.7480 - val_loss: 0.5250 - val_precision: 0.6990 - val_recall: 0.9179
# Epoch 25/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8036 - binary_accuracy: 0.7476 - loss: 0.4916 - precision: 0.6909 - recall: 0.9178
# Epoch 25: val_binary_accuracy did not improve from 0.74801
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.8036 - binary_accuracy: 0.7476 - loss: 0.4916 - precision: 0.6910 - recall: 0.9178 - val_auc: 0.7818 - val_binary_accuracy: 0.7263 - val_loss: 0.5296 - val_precision: 0.7109 - val_recall: 0.8116
# Epoch 26/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8152 - binary_accuracy: 0.7564 - loss: 0.4819 - precision: 0.7037 - recall: 0.9179
# Epoch 26: val_binary_accuracy did not improve from 0.74801
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - auc: 0.8152 - binary_accuracy: 0.7564 - loss: 0.4819 - precision: 0.7037 - recall: 0.9179 - val_auc: 0.7799 - val_binary_accuracy: 0.7325 - val_loss: 0.5351 - val_precision: 0.6722 - val_recall: 0.9624
# Epoch 27/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8075 - binary_accuracy: 0.7488 - loss: 0.4868 - precision: 0.6926 - recall: 0.9253
# Epoch 27: val_binary_accuracy did not improve from 0.74801
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0
saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - auc: 0.8444 - binary_accuracy: 0.7786 - loss: 0.4479 - precision: 0.7236 - recall: 0.9208 - val_auc: 0.8005 - val_binary_accuracy: 0.7574 - val_loss: 0.5317 - val_precision: 0.7121 - val_recall: 0.9072
# Epoch 44/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8447 - binary_accuracy: 0.7782 - loss: 0.4482 - precision: 0.7247 - recall: 0.9216
# Epoch 44: val_binary_accuracy did not improve from 0.75740
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.8447 - binary_accuracy: 0.7782 - loss: 0.4482 - precision: 0.7247 - recall: 0.9216 - val_auc: 0.7987 - val_binary_accuracy: 0.7527 - val_loss: 0.5390 - val_precision: 0.7207 - val_recall: 0.8677
# Epoch 45/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8525 - binary_accuracy: 0.7850 - loss: 0.4383 - precision: 0.7316 - recall: 0.9241
# Epoch 45: val_binary_accuracy improved from 0.75740 to 0.76114, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - auc: 0.8525 - binary_accuracy: 0.7850 - loss: 0.4383 - precision: 0.7316 - recall: 0.9241 - val_auc: 0.7999 - val_binary_accuracy: 0.7611 - val_loss: 0.5324 - val_precision: 0.7122 - val_recall: 0.9186
# Epoch 46/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8547 - binary_accuracy: 0.7888 - loss: 0.4338 - precision: 0.7316 - recall: 0.9290
# Epoch 46: val_binary_accuracy did not improve from 0.76114
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - auc: 0.8547 - binary_accuracy: 0.7888 - loss: 0.4338 - precision: 0.7317 - recall: 0.9290 - val_auc: 0.7775 - val_binary_accuracy: 0.7300 - val_loss: 0.5766 - val_precision: 0.6811 - val_recall: 0.9183
# Epoch 47/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8474 - binary_accuracy: 0.7823 - loss: 0.4419 - precision: 0.7272 - recall: 0.9227
# Epoch 47: val_binary_accuracy did not improve from 0.76114
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - auc: 0.8474 - binary_accuracy: 0.7824 - loss: 0.4419 - precision: 0.7272 - recall: 0.9227 - val_auc: 0.7960 - val_binary_accuracy: 0.7487 - val_loss: 0.5516 - val_precision: 0.6936 - val_recall: 0.9386
# Epoch 48/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8501 - binary_accuracy: 0.7855 - loss: 0.4377 - precision: 0.7290 - recall: 0.9238
# Epoch 48: val_binary_accuracy did not improve from 0.76114
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.8502 - binary_accuracy: 0.7854 - loss: 0.4377 - precision: 0.7290 - recall: 0.9238 - val_auc: 0.7539 - val_binary_accuracy: 0.6931 - val_loss: 0.6120 - val_precision: 0.6809 - val_recall: 0.7879
# Epoch 49/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8533 - binary_accuracy: 0.7838 - loss: 0.4368 - precision: 0.7299 - recall: 0.9199
# Epoch 49: val_binary_accuracy did not improve from 0.76114
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.8533 - binary_accuracy: 0.7838 - loss: 0.4368 - precision: 0.7299 - recall: 0.9200 - val_auc: 0.7456 - val_binary_accuracy: 0.7013 - val_loss: 0.6187 - val_precision: 0.6487 - val_recall: 0.9469
# Epoch 50/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8492 - binary_accuracy: 0.7805 - loss: 0.4390 - precision: 0.7280 - recall: 0.9243
# Epoch 50: val_binary_accuracy improved from 0.76114 to 0.76379, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_H/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - auc: 0.8492 - binary_accuracy: 0.7805 - loss: 0.4390 - precision: 0.7280 - recall: 0.9243 - val_auc: 0.8004 - val_binary_accuracy: 0.7638 - val_loss: 0.5514 - val_precision: 0.7274 - val_recall: 0.8837
