# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
path = "/content/drive/MyDrive/TFM/"
path1 = path + "Planets.csv"
path2 = path + "Not_Planets.csv"

# %%
#Creación del dataset con los registros de secuencias positivas y secuencias negativas
planets_df = pd.read_csv(path1, names=list(range(4000)))
not_planets_df = pd.read_csv(path2, names=list(range(4000)))
X_data = pd.concat([planets_df, not_planets_df]).to_numpy()
y_data = np.concatenate((np.ones(len(planets_df)), np.zeros(len(not_planets_df))))

#Separación en train y test
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.20, random_state=42)
y_train = np.transpose(np.atleast_2d(y_train))
y_test = np.transpose(np.atleast_2d(y_test))

# %%
#Definición del modelo a entrenar
from tensorflow.keras import layers
from tensorflow import keras

model_name = "Conv2D_G"

model = keras.Sequential(
    [
        layers.Input(shape=(4000,1)),
        layers.Reshape((500,8,1)),
        layers.Conv2D(filters=32, kernel_size=(2,1), activation='relu'),
        layers.MaxPooling2D(pool_size=(3,1)),
        layers.Conv2D(filters=32, kernel_size=(2,1), activation='relu'),
        layers.MaxPooling2D(pool_size=(3,1)),
        layers.Conv2D(filters=32, kernel_size=(2,1), activation='relu'),
        layers.MaxPooling2D(pool_size=(3,1)),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(100, activation='sigmoid'),
        layers.Dense(1, activation='sigmoid')
    ],
    name=model_name
)

# %%
from datetime import datetime
#Compilación del modelo
model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=[
              keras.metrics.BinaryAccuracy(),
              keras.metrics.Recall(),
              keras.metrics.Precision(),
              keras.metrics.AUC(num_thresholds=25)
            ]
    )

#Definición del directorio donde guardar los datos del entrenamiento
logdir = "/content/drive/MyDrive/TFM/Logs/" + model.name + "/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/TFM/Models/" + model_name + "/best_model.keras",
    verbose=1,
    save_best_only=True,
    mode="max",
    monitor="val_binary_accuracy",
)

# %%
training_history = model.fit(
    X_train,
    y_train,
    batch_size=64,
    verbose=1, # Suppress chatty output; use Tensorboard instead
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=[tensorboard_callback, model_checkpoint],
)
# Out:
# Epoch 1/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_2: 0.5937 - binary_accuracy: 0.5758 - loss: 0.6597 - precision_2: 0.5551 - recall_2: 0.7545
# Epoch 1: val_binary_accuracy improved from -inf to 0.64207, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - auc_2: 0.5937 - binary_accuracy: 0.5758 - loss: 0.6597 - precision_2: 0.5551 - recall_2: 0.7547 - val_auc_2: 0.6522 - val_binary_accuracy: 0.6421 - val_loss: 0.6271 - val_precision_2: 0.6009 - val_recall_2: 0.9585
# Epoch 2/50
# 514/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.6022 - binary_accuracy: 0.6015 - loss: 0.6454 - precision_2: 0.5694 - recall_2: 0.9195
# Epoch 2: val_binary_accuracy did not improve from 0.64207
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.6024 - binary_accuracy: 0.6016 - loss: 0.6453 - precision_2: 0.5695 - recall_2: 0.9194 - val_auc_2: 0.6317 - val_binary_accuracy: 0.5958 - val_loss: 0.6397 - val_precision_2: 0.6113 - val_recall_2: 0.6435
# Epoch 3/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.6320 - binary_accuracy: 0.6239 - loss: 0.6267 - precision_2: 0.5883 - recall_2: 0.8978
# Epoch 3: val_binary_accuracy improved from 0.64207 to 0.65146, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - auc_2: 0.6320 - binary_accuracy: 0.6238 - loss: 0.6267 - precision_2: 0.5883 - recall_2: 0.8978 - val_auc_2: 0.6493 - val_binary_accuracy: 0.6515 - val_loss: 0.6144 - val_precision_2: 0.6179 - val_recall_2: 0.8903
# Epoch 4/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.6297 - binary_accuracy: 0.6327 - loss: 0.6199 - precision_2: 0.5923 - recall_2: 0.9275
# Epoch 4: val_binary_accuracy improved from 0.65146 to 0.65748, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.6297 - binary_accuracy: 0.6327 - loss: 0.6199 - precision_2: 0.5923 - recall_2: 0.9275 - val_auc_2: 0.6355 - val_binary_accuracy: 0.6575 - val_loss: 0.6042 - val_precision_2: 0.6194 - val_recall_2: 0.9108
# Epoch 5/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.6473 - binary_accuracy: 0.6417 - loss: 0.6089 - precision_2: 0.5965 - recall_2: 0.9384
# Epoch 5: val_binary_accuracy improved from 0.65748 to 0.66614, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.6473 - binary_accuracy: 0.6417 - loss: 0.6089 - precision_2: 0.5965 - recall_2: 0.9385 - val_auc_2: 0.6821 - val_binary_accuracy: 0.6661 - val_loss: 0.5935 - val_precision_2: 0.6189 - val_recall_2: 0.9562
# Epoch 6/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_2: 0.6524 - binary_accuracy: 0.6430 - loss: 0.6102 - precision_2: 0.5985 - recall_2: 0.9461
# Epoch 6: val_binary_accuracy improved from 0.66614 to 0.67469, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.6525 - binary_accuracy: 0.6430 - loss: 0.6102 - precision_2: 0.5985 - recall_2: 0.9460 - val_auc_2: 0.6815 - val_binary_accuracy: 0.6747 - val_loss: 0.5878 - val_precision_2: 0.6254 - val_recall_2: 0.9567
# Epoch 7/50
# 515/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.6761 - binary_accuracy: 0.6592 - loss: 0.5922 - precision_2: 0.6112 - recall_2: 0.9387
# Epoch 7: val_binary_accuracy did not improve from 0.67469
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.6761 - binary_accuracy: 0.6591 - loss: 0.5923 - precision_2: 0.6112 - recall_2: 0.9387 - val_auc_2: 0.6689 - val_binary_accuracy: 0.6540 - val_loss: 0.6039 - val_precision_2: 0.6061 - val_recall_2: 0.9836
# Epoch 8/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.6823 - binary_accuracy: 0.6500 - loss: 0.5974 - precision_2: 0.6025 - recall_2: 0.9396
# Epoch 8: val_binary_accuracy improved from 0.67469 to 0.68336, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.6824 - binary_accuracy: 0.6501 - loss: 0.5974 - precision_2: 0.6026 - recall_2: 0.9395 - val_auc_2: 0.7023 - val_binary_accuracy: 0.6834 - val_loss: 0.5810 - val_precision_2: 0.6367 - val_recall_2: 0.9318
# Epoch 9/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.6974 - binary_accuracy: 0.6638 - loss: 0.5869 - precision_2: 0.6166 - recall_2: 0.9340
# Epoch 9: val_binary_accuracy did not improve from 0.68336
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.6974 - binary_accuracy: 0.6637 - loss: 0.5869 - precision_2: 0.6166 - recall_2: 0.9340 - val_auc_2: 0.7115 - val_binary_accuracy: 0.6781 - val_loss: 0.5825 - val_precision_2: 0.6325 - val_recall_2: 0.9311
# Epoch 10/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7149 - binary_accuracy: 0.6700 - loss: 0.5778 - precision_2: 0.6192 - recall_2: 0.9252
# Epoch 10: val_binary_accuracy improved from 0.68336 to 0.68541, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - auc_2: 0.7149 - binary_accuracy: 0.6700 - loss: 0.5778 - precision_2: 0.6192 - recall_2: 0.9252 - val_auc_2: 0.7267 - val_binary_accuracy: 0.6854 - val_loss: 0.5773 - val_precision_2: 0.6425 - val_recall_2: 0.9108
# Epoch 11/50
# 514/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7195 - binary_accuracy: 0.6692 - loss: 0.5757 - precision_2: 0.6193 - recall_2: 0.9294
# Epoch 11: val_binary_accuracy did not improve from 0.68541
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.7195 - binary_accuracy: 0.6692 - loss: 0.5757 - precision_2: 0.6194 - recall_2: 0.9294 - val_auc_2: 0.7104 - val_binary_accuracy: 0.6838 - val_loss: 0.5769 - val_precision_2: 0.6350 - val_recall_2: 0.9432
# Epoch 12/50
# 516/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.7202 - binary_accuracy: 0.6756 - loss: 0.5735 - precision_2: 0.6272 - recall_2: 0.9255
# Epoch 12: val_binary_accuracy did not improve from 0.68541
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.7203 - binary_accuracy: 0.6756 - loss: 0.5735 - precision_2: 0.6272 - recall_2: 0.9255 - val_auc_2: 0.7229 - val_binary_accuracy: 0.6829 - val_loss: 0.5760 - val_precision_2: 0.6403 - val_recall_2: 0.9108
# Epoch 13/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_2: 0.7349 - binary_accuracy: 0.6803 - loss: 0.5669 - precision_2: 0.6300 - recall_2: 0.9184
# Epoch 13: val_binary_accuracy improved from 0.68541 to 0.69010, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - auc_2: 0.7349 - binary_accuracy: 0.6803 - loss: 0.5669 - precision_2: 0.6300 - recall_2: 0.9184 - val_auc_2: 0.7367 - val_binary_accuracy: 0.6901 - val_loss: 0.5711 - val_precision_2: 0.6488 - val_recall_2: 0.8999
# Epoch 14/50
# 514/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.7354 - binary_accuracy: 0.6821 - loss: 0.5648 - precision_2: 0.6330 - recall_2: 0.9121
# Epoch 14: val_binary_accuracy did not improve from 0.69010
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - auc_2: 0.7353 - binary_accuracy: 0.6820 - loss: 0.5648 - precision_2: 0.6329 - recall_2: 0.9122 - val_auc_2: 0.7231 - val_binary_accuracy: 0.6725 - val_loss: 0.5814 - val_precision_2: 0.6499 - val_recall_2: 0.8230
# Epoch 15/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_2: 0.7447 - binary_accuracy: 0.6858 - loss: 0.5600 - precision_2: 0.6347 - recall_2: 0.9136
# Epoch 15: val_binary_accuracy did not improve from 0.69010
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - auc_2: 0.7446 - binary_accuracy: 0.6858 - loss: 0.5600 - precision_2: 0.6347 - recall_2: 0.9135 - val_auc_2: 0.7337 - val_binary_accuracy: 0.6826 - val_loss: 0.5732 - val_precision_2: 0.6481 - val_recall_2: 0.8725
# Epoch 16/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.7523 - binary_accuracy: 0.6957 - loss: 0.5546 - precision_2: 0.6462 - recall_2: 0.9078
# Epoch 16: val_binary_accuracy did not improve from 0.69010
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.7523 - binary_accuracy: 0.6957 - loss: 0.5546 - precision_2: 0.6462 - recall_2: 0.9077 - val_auc_2: 0.7515 - val_binary_accuracy: 0.6879 - val_loss: 0.5690 - val_precision_2: 0.6987 - val_recall_2: 0.7188
# Epoch 17/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7479 - binary_accuracy: 0.6905 - loss: 0.5577 - precision_2: 0.6471 - recall_2: 0.8863
# Epoch 17: val_binary_accuracy did not improve from 0.69010
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.7479 - binary_accuracy: 0.6905 - loss: 0.5577 - precision_2: 0.6471 - recall_2: 0.8863 - val_auc_2: 0.6721 - val_binary_accuracy: 0.4965 - val_loss: 0.9966 - val_precision_2: 0.7087 - val_recall_2: 0.0782
# Epoch 18/50
# 516/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7296 - binary_accuracy: 0.6750 - loss: 0.5757 - precision_2: 0.6326 - recall_2: 0.8744
# Epoch 18: val_binary_accuracy did not improve from 0.69010
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.7297 - binary_accuracy: 0.6752 - loss: 0.5756 - precision_2: 0.6326 - recall_2: 0.8747 - val_auc_2: 0.7544 - val_binary_accuracy: 0.6860 - val_loss: 0.5736 - val_precision_2: 0.6335 - val_recall_2: 0.9615
# Epoch 19/50
# 514/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.7546 - binary_accuracy: 0.6950 - loss: 0.5506 - precision_2: 0.6442 - recall_2: 0.9064
# Epoch 19: val_binary_accuracy improved from 0.69010 to 0.69239, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.7547 - binary_accuracy: 0.6951 - loss: 0.5506 - precision_2: 0.6443 - recall_2: 0.9063 - val_auc_2: 0.7607 - val_binary_accuracy: 0.6924 - val_loss: 0.5654 - val_precision_2: 0.7064 - val_recall_2: 0.7140
# Epoch 20/50
# 516/520 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_2: 0.7714 - binary_accuracy: 0.7011 - loss: 0.5391 - precision_2: 0.6613 - recall_2: 0.8545
# Epoch 20: val_binary_accuracy improved from 0.69239 to 0.70238, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - auc_2: 0.7714 - binary_accuracy: 0.7012 - loss: 0.5391 - precision_2: 0.6613 - recall_2: 0.8547 - val_auc_2: 0.7624 - val_binary_accuracy: 0.7024 - val_loss: 0.5603 - val_precision_2: 0.6466 - val_recall_2: 0.9617
# Epoch 21/50
# 515/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7700 - binary_accuracy: 0.7097 - loss: 0.5373 - precision_2: 0.6638 - recall_2: 0.8907
# Epoch 21: val_binary_accuracy did not improve from 0.70238
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.7700 - binary_accuracy: 0.7096 - loss: 0.5374 - precision_2: 0.6637 - recall_2: 0.8906 - val_auc_2: 0.7404 - val_binary_accuracy: 0.6872 - val_loss: 0.5695 - val_precision_2: 0.6524 - val_recall_2: 0.8720
# Epoch 22/50
# 516/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7644 - binary_accuracy: 0.7062 - loss: 0.5436 - precision_2: 0.6590 - recall_2: 0.8924
# Epoch 22: val_binary_accuracy did not improve from 0.70238
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.7644 - binary_accuracy: 0.7062 - loss: 0.5435 - precision_2: 0.6591 - recall_2: 0.8924 - val_auc_2: 0.7650 - val_binary_accuracy: 0.6999 - val_loss: 0.5610 - val_precision_2: 0.6447 - val_recall_2: 0.9610
# Epoch 23/50
# 514/520 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_2: 0.7737 - binary_accuracy: 0.7087 - loss: 0.5362 - precision_2: 0.6655 - recall_2: 0.8786
# Epoch 23: val_binary_accuracy improved from 0.70238 to 0.71358, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - auc_2: 0.7736 - binary_accuracy: 0.7086 - loss: 0.5362 - precision_2: 0.6655 - recall_2: 0.8787 - val_auc_2: 0.7546 - val_binary_accuracy: 0.7136 - val_loss: 0.5652 - val_precision_2: 0.6673 - val_recall_2: 0.9120
# Epoch 24/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7795 - binary_accuracy: 0.7129 - loss: 0.5302 - precision_2: 0.6688 - recall_2: 0.8765
# Epoch 24: val_binary_accuracy did not improve from 0.71358
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.7795 - binary_accuracy: 0.7129 - loss: 0.5302 - precision_2: 0.6688 - recall_2: 0.8765 - val_auc_2: 0.7523 - val_binary_accuracy: 0.6332 - val_loss: 0.5850 - val_precision_2: 0.7023 - val_recall_2: 0.5294
# Epoch 25/50
# 516/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7868 - binary_accuracy: 0.7228 - loss: 0.5219 - precision_2: 0.6747 - recall_2: 0.8863
# Epoch 25: val_binary_accuracy did not improve from 0.71358
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.7868 - binary_accuracy: 0.7228 - loss: 0.5219 - precision_2: 0.6747 - recall_2: 0.8863 - val_auc_2: 0.7508 - val_binary_accuracy: 0.5691 - val_loss: 0.6692 - val_precision_2: 0.7450 - val_recall_2: 0.2792
# Epoch 26/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.7855 - binary_accuracy: 0.7171 - loss: 0.5273 - precision_2: 0.6805 - recall_2: 0.8625
# Epoch 26: val_binary_accuracy did not improve from 0.71358
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.7855 - binary_accuracy: 0.7171 - loss: 0.5273 - precision_2: 0.6805 - recall_2: 0.8626 - val_auc_2: 0.7657 - val_binary_accuracy: 0.7059 - val_loss: 0.5582 - val_precision_2: 0.6518 - val_recall_2: 0.9505
# Epoch 27/50
# 514/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.7970 - binary_accuracy: 0.7255 - loss: 0.5144 - precision_2: 0.6819 - recall_2: 0.8839
# Epoch 27: val_binary_accuracy improved from 0.71358 to 0.72598, saving model to /content/drive/MyDrive/TFM/Models/Conv2D_G/best_model.keras
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.7969 - binary_accuracy: 0.7255 - loss: 0.5144 - precision_2: 0.6819 - recall_2: 0.8838 - val_auc_2: 0.7682 - val_binary_accuracy: 0.7260 - val_loss: 0.5491 - val_precision_2: 0.6912 - val_recall_2: 0.8691
# Epoch 28/50
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.7905 - binary_accuracy: 0.7226 - loss: 0.5192 - precision_2: 0.6805 - recall_2: 0.8684
# Epoch 28: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - auc_2: 0.7905 - binary_accuracy: 0.7226 - loss: 0.5192 - precision_2: 0.6805 - recall_2: 0.8684 - val_auc_2: 0.7573 - val_binary_accuracy: 0.6586 - val_loss: 0.5910 - val_precision_2: 0.7075 - val_recall_2: 0.6020
# Epoch 29/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7998 - binary_accuracy: 0.7353 - loss: 0.5102 - precision_2: 0.6937 - recall_2: 0.8777
# Epoch 29: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.7997 - binary_accuracy: 0.7353 - loss: 0.5102 - precision_2: 0.6937 - recall_2: 0.8777 - val_auc_2: 0.7686 - val_binary_accuracy: 0.6988 - val_loss: 0.5644 - val_precision_2: 0.7169 - val_recall_2: 0.7094
# Epoch 30/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7998 - binary_accuracy: 0.7338 - loss: 0.5090 - precision_2: 0.6882 - recall_2: 0.8796
# Epoch 30: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.7997 - binary_accuracy: 0.7338 - loss: 0.5090 - precision_2: 0.6881 - recall_2: 0.8796 - val_auc_2: 0.7708 - val_binary_accuracy: 0.7176 - val_loss: 0.5491 - val_precision_2: 0.6648 - val_recall_2: 0.9375
# Epoch 31/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.8033 - binary_accuracy: 0.7353 - loss: 0.5045 - precision_2: 0.6911 - recall_2: 0.8847
# Epoch 31: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.8033 - binary_accuracy: 0.7353 - loss: 0.5045 - precision_2: 0.6911 - recall_2: 0.8847 - val_auc_2: 0.7574 - val_binary_accuracy: 0.7138 - val_loss: 0.5590 - val_precision_2: 0.6850 - val_recall_2: 0.8474
# Epoch 32/50
# 515/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7986 - binary_accuracy: 0.7298 - loss: 0.5097 - precision_2: 0.6902 - recall_2: 0.8700
# Epoch 32: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.7986 - binary_accuracy: 0.7299 - loss: 0.5096 - precision_2: 0.6902 - recall_2: 0.8701 - val_auc_2: 0.7574 - val_binary_accuracy: 0.6882 - val_loss: 0.5804 - val_precision_2: 0.7034 - val_recall_2: 0.7076
# Epoch 33/50
# 513/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.7986 - binary_accuracy: 0.7278 - loss: 0.5105 - precision_2: 0.6851 - recall_2: 0.8666
# Epoch 33: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - auc_2: 0.7987 - binary_accuracy: 0.7279 - loss: 0.5105 - precision_2: 0.6851 - recall_2: 0.8669 - val_auc_2: 0.7668 - val_binary_accuracy: 0.7212 - val_loss: 0.5506 - val_precision_2: 0.6731 - val_recall_2: 0.9170
# Epoch 34/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.8056 - binary_accuracy: 0.7342 - loss: 0.5026 - precision_2: 0.6892 - recall_2: 0.8792
# Epoch 34: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - auc_2: 0.8056 - binary_accuracy: 0.7343 - loss: 0.5026 - precision_2: 0.6893 - recall_2: 0.8792 - val_auc_2: 0.7584 - val_binary_accuracy: 0.7143 - val_loss: 0.5615 - val_precision_2: 0.6645 - val_recall_2: 0.9266
# Epoch 35/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.8105 - binary_accuracy: 0.7413 - loss: 0.4978 - precision_2: 0.6951 - recall_2: 0.8881
# Epoch 35: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - auc_2: 0.8105 - binary_accuracy: 0.7413 - loss: 0.4978 - precision_2: 0.6951 - recall_2: 0.8881 - val_auc_2: 0.7708 - val_binary_accuracy: 0.7233 - val_loss: 0.5510 - val_precision_2: 0.7036 - val_recall_2: 0.8221
# Epoch 36/50
# 516/520 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_2: 0.8083 - binary_accuracy: 0.7362 - loss: 0.5006 - precision_2: 0.6944 - recall_2: 0.8801
# Epoch 36: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - auc_2: 0.8084 - binary_accuracy: 0.7363 - loss: 0.5006 - precision_2: 0.6944 - recall_2: 0.8801 - val_auc_2: 0.7510 - val_binary_accuracy: 0.6860 - val_loss: 0.5702 - val_precision_2: 0.6914 - val_recall_2: 0.7318
# Epoch 37/50
# 516/520 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_2: 0.7489 - binary_accuracy: 0.6843 - loss: 0.5528 - precision_2: 0.6457 - recall_2: 0.8585
# Epoch 37: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - auc_2: 0.7491 - binary_accuracy: 0.6845 - loss: 0.5526 - precision_2: 0.6459 - recall_2: 0.8586 - val_auc_2: 0.7572 - val_binary_accuracy: 0.7018 - val_loss: 0.5717 - val_precision_2: 0.6506 - val_recall_2: 0.9396
# Epoch 38/50
# 518/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.7721 - binary_accuracy: 0.7065 - loss: 0.5331 - precision_2: 0.6606 - recall_2: 0.8885
# Epoch 38: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - auc_2: 0.7722 - binary_accuracy: 0.7065 - loss: 0.5330 - precision_2: 0.6607 - recall_2: 0.8885 - val_auc_2: 0.7484 - val_binary_accuracy: 0.6890 - val_loss: 0.5769 - val_precision_2: 0.6855 - val_recall_2: 0.7591
# Epoch 39/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_2: 0.8045 - binary_accuracy: 0.7334 - loss: 0.5035 - precision_2: 0.6890 - recall_2: 0.8800
# Epoch 39: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - auc_2: 0.8045 - binary_accuracy: 0.7334 - loss: 0.5035 - precision_2: 0.6890 - recall_2: 0.8800 - val_auc_2: 0.7554 - val_binary_accuracy: 0.7121 - val_loss: 0.5644 - val_precision_2: 0.6862 - val_recall_2: 0.8376
# Epoch 40/50
# 515/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.8091 - binary_accuracy: 0.7404 - loss: 0.5008 - precision_2: 0.6943 - recall_2: 0.8835
# Epoch 40: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - auc_2: 0.8090 - binary_accuracy: 0.7404 - loss: 0.5008 - precision_2: 0.6943 - recall_2: 0.8835 - val_auc_2: 0.7548 - val_binary_accuracy: 0.7143 - val_loss: 0.5654 - val_precision_2: 0.6678 - val_recall_2: 0.9126
# Epoch 41/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_2: 0.8152 - binary_accuracy: 0.7418 - loss: 0.4932 - precision_2: 0.6955 - recall_2: 0.8890
# Epoch 41: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.8151 - binary_accuracy: 0.7418 - loss: 0.4932 - precision_2: 0.6956 - recall_2: 0.8889 - val_auc_2: 0.7639 - val_binary_accuracy: 0.7078 - val_loss: 0.5638 - val_precision_2: 0.7021 - val_recall_2: 0.7753
# Epoch 42/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.8212 - binary_accuracy: 0.7448 - loss: 0.4868 - precision_2: 0.7005 - recall_2: 0.8780
# Epoch 42: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.8212 - binary_accuracy: 0.7448 - loss: 0.4869 - precision_2: 0.7005 - recall_2: 0.8780 - val_auc_2: 0.7647 - val_binary_accuracy: 0.7219 - val_loss: 0.5584 - val_precision_2: 0.6855 - val_recall_2: 0.8741
# Epoch 43/50
# 519/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.8202 - binary_accuracy: 0.7476 - loss: 0.4865 - precision_2: 0.7031 - recall_2: 0.8920
# Epoch 43: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - auc_2: 0.8202 - binary_accuracy: 0.7476 - loss: 0.4866 - precision_2: 0.7031 - recall_2: 0.8920 - val_auc_2: 0.7604 - val_binary_accuracy: 0.7162 - val_loss: 0.5645 - val_precision_2: 0.6883 - val_recall_2: 0.8449
# Epoch 44/50
# 513/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.8127 - binary_accuracy: 0.7398 - loss: 0.4952 - precision_2: 0.6949 - recall_2: 0.8823
# Epoch 44: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.8126 - binary_accuracy: 0.7397 - loss: 0.4953 - precision_2: 0.6948 - recall_2: 0.8822 - val_auc_2: 0.7575 - val_binary_accuracy: 0.7168 - val_loss: 0.5709 - val_precision_2: 0.6937 - val_recall_2: 0.8298
# Epoch 45/50
# 515/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.8147 - binary_accuracy: 0.7429 - loss: 0.4908 - precision_2: 0.6981 - recall_2: 0.8868
# Epoch 45: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.8147 - binary_accuracy: 0.7429 - loss: 0.4908 - precision_2: 0.6981 - recall_2: 0.8868 - val_auc_2: 0.7510 - val_binary_accuracy: 0.7161 - val_loss: 0.5724 - val_precision_2: 0.6773 - val_recall_2: 0.8825
# Epoch 46/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.8225 - binary_accuracy: 0.7467 - loss: 0.4853 - precision_2: 0.7028 - recall_2: 0.8731
# Epoch 46: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - auc_2: 0.8225 - binary_accuracy: 0.7467 - loss: 0.4853 - precision_2: 0.7028 - recall_2: 0.8732 - val_auc_2: 0.7601 - val_binary_accuracy: 0.7026 - val_loss: 0.5758 - val_precision_2: 0.6529 - val_recall_2: 0.9323
# Epoch 47/50
# 515/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.8294 - binary_accuracy: 0.7525 - loss: 0.4757 - precision_2: 0.7058 - recall_2: 0.8930
# Epoch 47: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - auc_2: 0.8294 - binary_accuracy: 0.7525 - loss: 0.4757 - precision_2: 0.7058 - recall_2: 0.8930 - val_auc_2: 0.7678 - val_binary_accuracy: 0.7259 - val_loss: 0.5586 - val_precision_2: 0.6856 - val_recall_2: 0.8875
# Epoch 48/50
# 515/520 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_2: 0.8292 - binary_accuracy: 0.7528 - loss: 0.4784 - precision_2: 0.7101 - recall_2: 0.8793
# Epoch 48: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - auc_2: 0.8292 - binary_accuracy: 0.7528 - loss: 0.4784 - precision_2: 0.7101 - recall_2: 0.8793 - val_auc_2: 0.7600 - val_binary_accuracy: 0.7077 - val_loss: 0.5722 - val_precision_2: 0.6999 - val_recall_2: 0.7810
# Epoch 49/50
# 517/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.8354 - binary_accuracy: 0.7602 - loss: 0.4686 - precision_2: 0.7181 - recall_2: 0.8853
# Epoch 49: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.8353 - binary_accuracy: 0.7602 - loss: 0.4686 - precision_2: 0.7181 - recall_2: 0.8853 - val_auc_2: 0.7599 - val_binary_accuracy: 0.7157 - val_loss: 0.5714 - val_precision_2: 0.7003 - val_recall_2: 0.8068
# Epoch 50/50
# 514/520 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_2: 0.8361 - binary_accuracy: 0.7547 - loss: 0.4677 - precision_2: 0.7114 - recall_2: 0.8855
# Epoch 50: val_binary_accuracy did not improve from 0.72598
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - auc_2: 0.8361 - binary_accuracy: 0.7547 - loss: 0.4678 - precision_2: 0.7114 - recall_2: 0.8856 - val_auc_2: 0.7660 - val_binary_accuracy: 0.7235 - val_loss: 0.5646 - val_precision_2: 0.6994 - val_recall_2: 0.8349
