# %%
import pandas as pd
PC_df = pd.read_csv('PC.csv', header=36)
AFP_df = pd.read_csv('AFP.csv', header=36)
NTP_df = pd.read_csv('NTP.csv', header=35)
UKN_df = pd.read_csv('UKN.csv', header=35)

# %%
PC_df
# Out:
#          kepid  tce_plnt_num av_training_set  tce_rogue_flag  tce_period  \
# 0      6666233             1              PC             NaN    0.512409
# 1      5773121             1              PC             NaN    0.524187
# 2     11246161             1              PC             NaN    0.537357
# 3      9967771             1              PC             NaN    0.538345
# 4      5340878             1              PC             NaN    0.539914
# ...        ...           ...             ...             ...         ...
# 2731   8805348             1              PC             NaN   29.907300
# 2732   3559935             1              PC             NaN   29.911300
# 2733   9993683             1              PC             NaN   29.937100
# 2734   8151055             1              PC             NaN   29.963400
# 2735   8613535             1              PC             NaN   29.968600
#
#       tce_period_err  tce_time0bk  tce_time0bk_err  tce_impact  \
# ...

# %%
AFP_df
# Out:
#         kepid  tce_plnt_num av_training_set  tce_rogue_flag  tce_period  \
# 0     2439211             2             AFP             NaN    0.499972
# 1     2439211             1             AFP             NaN    0.499978
# 2     8760767             2             AFP             NaN    0.500097
# 3     8760767             1             AFP             NaN    0.500172
# 4     9305574             1             AFP             NaN    0.500425
# ...       ...           ...             ...             ...         ...
# 9037  5360974             2             AFP             NaN   29.804400
# 9038  6431670             1             AFP             NaN   29.911300
# 9039  6431670             2             AFP             NaN   29.911500
# 9040  7810483             1             AFP             NaN   29.922100
# 9041  3098843             1             AFP             NaN   29.975800
#
#       tce_period_err  tce_time0bk  tce_time0bk_err  tce_impact  \
# ...

# %%
NTP_df
# Out:
#          kepid  tce_plnt_num av_training_set  tce_rogue_flag  tce_period  \
# 0       892667             1             NTP             NaN    2.262110
# 1      1292087             1             NTP             NaN    0.547626
# 2      1574792             1             NTP             NaN    1.391750
# 3      1865567             1             NTP             NaN    0.674634
# 4      2019227             1             NTP             NaN    2.980320
# ...        ...           ...             ...             ...         ...
# 2536  11807603             1             NTP             NaN    1.573010
# 2537  12353501             1             NTP             NaN  459.293000
# 2538  12417370             1             NTP             NaN  595.156000
# 2539  12508604             2             NTP             NaN    0.557521
# 2540  11717240             1             NTP             NaN    1.035500
#
#       tce_period_err  tce_time0bk  tce_time0bk_err  tce_impact  \
# ...

# %%
UKN_df
# Out:
#          kepid  tce_plnt_num av_training_set  tce_rogue_flag  tce_period  \
# 0      1292087             2             UNK             NaN    1.095240
# 1      1293031             2             UNK             NaN    0.719273
# 2      1164109             1             UNK             NaN  622.408000
# 3      1026032             1             UNK             NaN    8.460440
# 4      1026032             2             UNK             NaN    4.230220
# ...        ...           ...             ...             ...         ...
# 4625  11809145             1             UNK             NaN    1.067020
# 4626  11809179             1             UNK             NaN    0.972957
# 4627  11809179             2             UNK             NaN    2.708050
# 4628  11809346             1             UNK             NaN    0.624575
# 4629  11906217             1             UNK             NaN   37.910200
#
#       tce_period_err  tce_time0bk  tce_time0bk_err  tce_impact  \
# ...

# %%
PC_stars = PC_df['kepid'].unique()
len(PC_stars)
# Out:
# 2130

# %%
AFP_stars = AFP_df['kepid'].unique()
len(AFP_stars)
# Out:
# 4951

# %%
AFP_toRemove_df = AFP_df[AFP_df['kepid'].isin(PC_stars)]
AFP_toRemove_df.head()
# Out:
#          kepid  tce_plnt_num av_training_set  tce_rogue_flag  tce_period  \
# 325    5080636             2             AFP             NaN    0.530664
# 327    5080636             3             AFP             NaN    0.530781
# 454    8894646             2             AFP             NaN    0.541987
# 1341  11968463             3             AFP             NaN    0.646743
# 1387   8030339             1             AFP             NaN    0.652450
#
#       tce_period_err  tce_time0bk  tce_time0bk_err  tce_impact  \
# 325         0.000009      131.739         0.001226     0.18520
# 327         0.000029      131.523         0.005662     0.79800
# 454         0.000012      131.898         0.005971     0.02645
# 1341        0.000007      132.026         0.001226     0.10000
# 1387        0.000003      132.053         0.000635     0.50000
#
#       tce_impact_err  ...  tce_eqt  tce_eqt_err  tce_insol  tce_insol_err  \
# ...

# %%
len(AFP_toRemove_df)
# Out:
# 58

# %%
Positive_df = PC_df
Negative_df = AFP_df.drop(AFP_toRemove_df.index, axis=0, inplace=False)

# %%
combined_df = UKN_df
print(len(NTP_df))
print(len(UKN_df))
print(len(NTP_df) + len(UKN_df))
# Out:
# 2541
# 4630
# 7171

# %%
for i in range(len(NTP_df)):
    combined_df.loc[len(combined_df)] = UKN_df.loc[i]
len(combined_df)
# Out:
# 7171

# %%
combined_stars = combined_df['kepid'].unique()

# %%
NT_toremove_df = combined_df[combined_df['kepid'].isin(PC_stars) | combined_df['kepid'].isin(AFP_stars)]
Not_Planet_df = combined_df.drop(NT_toremove_df.index, axis=0, inplace=False)

# %%
Positive_df
# Out:
#          kepid  tce_plnt_num av_training_set  tce_rogue_flag  tce_period  \
# 0      6666233             1              PC             NaN    0.512409
# 1      5773121             1              PC             NaN    0.524187
# 2     11246161             1              PC             NaN    0.537357
# 3      9967771             1              PC             NaN    0.538345
# 4      5340878             1              PC             NaN    0.539914
# ...        ...           ...             ...             ...         ...
# 2731   8805348             1              PC             NaN   29.907300
# 2732   3559935             1              PC             NaN   29.911300
# 2733   9993683             1              PC             NaN   29.937100
# 2734   8151055             1              PC             NaN   29.963400
# 2735   8613535             1              PC             NaN   29.968600
#
#       tce_period_err  tce_time0bk  tce_time0bk_err  tce_impact  \
# ...

# %%
Negative_df
# Out:
#         kepid  tce_plnt_num av_training_set  tce_rogue_flag  tce_period  \
# 0     2439211             2             AFP             NaN    0.499972
# 1     2439211             1             AFP             NaN    0.499978
# 2     8760767             2             AFP             NaN    0.500097
# 3     8760767             1             AFP             NaN    0.500172
# 4     9305574             1             AFP             NaN    0.500425
# ...       ...           ...             ...             ...         ...
# 9037  5360974             2             AFP             NaN   29.804400
# 9038  6431670             1             AFP             NaN   29.911300
# 9039  6431670             2             AFP             NaN   29.911500
# 9040  7810483             1             AFP             NaN   29.922100
# 9041  3098843             1             AFP             NaN   29.975800
#
#       tce_period_err  tce_time0bk  tce_time0bk_err  tce_impact  \
# ...

# %%
Not_Planet_df
# Out:
#         kepid  tce_plnt_num av_training_set  tce_rogue_flag  tce_period  \
# 0     1292087             2             UNK             NaN    1.095240
# 1     1293031             2             UNK             NaN    0.719273
# 2     1164109             1             UNK             NaN  622.408000
# 3     1026032             1             UNK             NaN    8.460440
# 4     1026032             2             UNK             NaN    4.230220
# ...       ...           ...             ...             ...         ...
# 7165  7505674             1             UNK             NaN    1.600100
# 7166  7505674             2             UNK             NaN    0.800136
# 7168  7624741             2             UNK             NaN    1.402750
# 7169  7767774             1             UNK             NaN    0.728954
# 7170  7352995             1             UNK             NaN    0.719390
#
#       tce_period_err  tce_time0bk  tce_time0bk_err  tce_impact  \
# ...

# %%
print(len(Positive_df['kepid'].unique()))
print(len(Negative_df['kepid'].unique()))
print(len(Not_Planet_df['kepid'].unique()))
# Out:
# 2130
# 4907
# 3200
